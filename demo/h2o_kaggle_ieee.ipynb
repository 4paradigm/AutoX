# %%
import pandas as pd
import numpy as np
import os

# %%
import h2o
from h2o.automl import H2OAutoML
h2o.init()
# Out:
# Checking whether there is an H2O instance running at http://localhost:54321 ..... not found.
# Attempting to start a local H2O server...
#   Java Version: java version "1.8.0_11"; Java(TM) SE Runtime Environment (build 1.8.0_11-b12); Java HotSpot(TM) 64-Bit Server VM (build 25.11-b03, mixed mode)
#   Starting server from /home/caihengxing/anaconda3/lib/python3.7/site-packages/h2o/backend/bin/h2o.jar
#   Ice root: /tmp/tmph5bj6aqs
#   JVM stdout: /tmp/tmph5bj6aqs/h2o_caihengxing_started_from_python.out
#   JVM stderr: /tmp/tmph5bj6aqs/h2o_caihengxing_started_from_python.err
#   Server is running at http://127.0.0.1:54321
# Connecting to H2O server at http://127.0.0.1:54321 ... successful.
# --------------------------  ------------------------------------------------------------------
# H2O_cluster_uptime:         02 secs
# H2O_cluster_timezone:       Asia/Shanghai
# H2O_data_parsing_timezone:  UTC
# H2O_cluster_version:        3.32.1.5
# H2O_cluster_version_age:    26 days
# ...

# %%
train_path = '../autox/data/kaggle_ieee/train_transaction.csv'
test_path = '../autox/data/kaggle_ieee/test_transaction.csv'

# %%
# Load data into H2O
train = h2o.import_file(train_path)
test  = h2o.import_file(test_path)
# Out:
# Parse progress: |█████████████████████████████████████████████████████████| 100%
# Parse progress: |█████████████████████████████████████████████████████████| 100%

# %%
train.head()
# Out:
# <table>
# <thead>
# ...

# %%
y = "isFraud"

# %%
aml2 = H2OAutoML(max_runtime_secs = 7200, seed = 1, project_name = "kaggle_ieee")
aml2.train(y = y, training_frame = train)
# Out:
# AutoML progress: |████████████████████████████████████████████████████████| 100%

# %%
pred = aml2.predict(test)
# Out:
# stackedensemble prediction progress: |████████████████████████████████████| 100%
# /home/caihengxing/anaconda3/lib/python3.7/site-packages/h2o/job.py:72: UserWarning: Test/Validation dataset column 'P_emaildomain' has levels not trained on: ["scranton.edu"]
#   warnings.warn(w)

# %%
sub = pd.read_csv(test_path)
sub = sub[['TransactionID']]

# %%
pred = h2o.as_list(pred)

# %%
sub[y] = pred['predict']

# %%
sub.to_csv("./h2o_sub_kaggle_ieee.csv", index = False)
