# %% [markdown]
# ## 导入所需的包

# %%
from autox import AutoX
# Out:
# /home/caihengxing/anaconda3/lib/python3.7/site-packages/pandas/compat/_optional.py:138: UserWarning: Pandas requires version '2.7.0' or newer of 'numexpr' (version '2.6.9' currently installed).
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# ## 配置数据信息

# %%
# 选择数据集
data_name = '汽车销量预测'
path = f'../../data/{data_name}'

feature_type = {
    'test.csv': {
        'cityid': 'cat',
        'carid': 'cat',
        'time': 'datetime'},
    'train.csv': {
        'cityid': 'cat',
        'carid': 'cat',
        'time': 'datetime',
        'sales': 'num'}
}

autox = AutoX(target = 'sales', train_name = 'train.csv', test_name = 'test.csv', 
               id = ['cityid', 'carid'], path = path, time_series=True, ts_unit='month',time_col = 'time',
               feature_type = feature_type)
# Out:
#    INFO ->  [+] read test.csv
#    INFO ->  [+] read test.csv
#    INFO ->  Memory usage of dataframe is 0.05 MB
#    INFO ->  Memory usage of dataframe is 0.05 MB
#    INFO ->  Memory usage after optimization is: 0.01 MB
#    INFO ->  Memory usage after optimization is: 0.01 MB
#    INFO ->  Decreased by 86.6%
#    INFO ->  Decreased by 86.6%
#    INFO ->  table = test.csv, shape = (2304, 3)
#    INFO ->  table = test.csv, shape = (2304, 3)
#    INFO ->  [+] read train.csv
#    INFO ->  [+] read train.csv
#    INFO ->  Memory usage of dataframe is 0.21 MB
#    INFO ->  Memory usage of dataframe is 0.21 MB
#    INFO ->  Memory usage after optimization is: 0.03 MB
#    INFO ->  Memory usage after optimization is: 0.03 MB
#    INFO ->  Decreased by 83.7%
#    INFO ->  Decreased by 83.7%
#    INFO ->  table = train.csv, shape = (6912, 4)
#    INFO ->  table = train.csv, shape = (6912, 4)

# %%
sub = autox.get_submit_ts()
# Out:
#    INFO ->  start feature engineer
#    INFO ->  start feature engineer
#    INFO ->  feature engineer: one2M
#    INFO ->  feature engineer: one2M
#    INFO ->  featureOne2M ops: {}
#    INFO ->  featureOne2M ops: {}
#    INFO ->  ignore featureOne2M
#    INFO ->  ignore featureOne2M
#    INFO ->  feature engineer: time
#    INFO ->  feature engineer: time
#    INFO ->  featureTime ops: ['time']
#    INFO ->  featureTime ops: ['time']
# 100%|██████████| 1/1 [00:00<00:00, 45.35it/s]
#    INFO ->  feature engineer: ShiftTS
#    INFO ->  feature engineer: ShiftTS
#    INFO ->  featureShiftTS ops: ['sales']
#    INFO ->  featureShiftTS ops: ['sales']
#    INFO ->  featureShiftTS lags: [1, 2, 3]
#    INFO ->  featureShiftTS lags: [1, 2, 3]
# 1it [00:00,  9.66it/s]
#    INFO ->  feature engineer: RollingStatTS
#    INFO ->  feature engineer: RollingStatTS
#    INFO ->  featureRollingStatTS ops: ['sales']
#    INFO ->  featureRollingStatTS ops: ['sales']
#    INFO ->  featureRollingStatTS windows: [3, 4, 5]
#    INFO ->  featureRollingStatTS windows: [3, 4, 5]
# 100%|██████████| 1/1 [00:00<00:00,  1.04it/s]
#    INFO ->  feature engineer: ExpWeightedMean
#    INFO ->  feature engineer: ExpWeightedMean
#    INFO ->  featureExpWeightedMean ops: ['sales']
#    INFO ->  featureExpWeightedMean ops: ['sales']
#    INFO ->  featureExpWeightedMean lags: [1, 2, 3]
#    INFO ->  featureExpWeightedMean lags: [1, 2, 3]
# 1it [00:00,  4.25it/s]
# 100%|██████████| 4/4 [00:00<00:00, 243.39it/s]
#    INFO ->  label_encoder_list: ['cityid', 'carid']
#    INFO ->  label_encoder_list: ['cityid', 'carid']
#    INFO ->  ordinal_encoder_list: []
#    INFO ->  ordinal_encoder_list: []
#    INFO ->  feature combination
#    INFO ->  feature combination
# 100%|██████████| 5/5 [00:00<00:00, 1818.87it/s]
#    INFO ->  shape of FE_all: (9216, 37), shape of train: (6912, 37), shape of test: (2304, 37)
#    INFO ->  shape of FE_all: (9216, 37), shape of train: (6912, 37), shape of test: (2304, 37)
#    INFO ->  feature filter
#    INFO ->  feature filter
# 100%|██████████| 36/36 [00:00<00:00, 1276.29it/s]
#    INFO ->  filtered features: ['cityid', 'carid', 'sales', 'time_year', 'time_day', 'time_hour', 'time_is_month_start', 'time_is_month_end', 'cityid__carid__sales_roll_mean_3', 'cityid__carid__sales_roll_std_3', 'cityid__carid__sales_roll_median_3', 'cityid__carid__sales_roll_max_3', 'cityid__carid__sales_roll_min_3']
#    INFO ->  filtered features: ['cityid', 'carid', 'sales', 'time_year', 'time_day', 'time_hour', 'time_is_month_start', 'time_is_month_end', 'cityid__carid__sales_roll_mean_3', 'cityid__carid__sales_roll_std_3', 'cityid__carid__sales_roll_median_3', 'cityid__carid__sales_roll_max_3', 'cityid__carid__sales_roll_min_3']
#    INFO ->  used_features: ['cityid_encoder', 'carid_encoder', 'time_month', 'time_weekofyear', 'time_dayofweek', 'time_is_wknd', 'time_quarter', 'cityid__carid__sales__lag_1', 'cityid__carid__sales__lag_2', 'cityid__carid__sales__lag_3', 'cityid__carid__sales_roll_mean_4', 'cityid__carid__sales_roll_mean_5', 'cityid__carid__sales_roll_std_4', 'cityid__carid__sales_roll_std_5', 'cityid__carid__sales_roll_median_4', 'cityid__carid__sales_roll_median_5', 'cityid__carid__sales_roll_max_4', 'cityid__carid__sales_roll_max_5', 'cityid__carid__sales_roll_min_4', 'cityid__carid__sales_roll_min_5', 'cityid__carid__sales__ewm_1', 'cityid__carid__sales__ewm_2', 'cityid__carid__sales__ewm_3']
#    INFO ->  used_features: ['cityid_encoder', 'carid_encoder', 'time_month', 'time_weekofyear', 'time_dayofweek', 'time_is_wknd', 'time_quarter', 'cityid__carid__sales__lag_1', 'cityid__carid__sales__lag_2', 'cityid__carid__sales__lag_3', 'cityid__carid__sales_roll_mean_4', 'cityid__carid__sales_roll_mean_5', 'cityid__carid__sales_roll_std_4', 'cityid__carid__sales_roll_std_5', 'cityid__carid__sales_roll_median_4', 'cityid__carid__sales_roll_median_5', 'cityid__carid__sales_roll_max_4', 'cityid__carid__sales_roll_max_5', 'cityid__carid__sales_roll_min_4', 'cityid__carid__sales_roll_min_5', 'cityid__carid__sales__ewm_1', 'cityid__carid__sales__ewm_2', 'cityid__carid__sales__ewm_3']
#    INFO ->  start training lightgbm model
#    INFO ->  start training lightgbm model
#    INFO ->  (6912, 23)
#    INFO ->  (6912, 23)
#    INFO ->  log1p!
#    INFO ->  log1p!
#    INFO ->  train time, min and max:
#    INFO ->  train time, min and max:
#    INFO ->  2017-01-01, 2018-12-01
#    INFO ->  2017-01-01, 2018-12-01
#    INFO ->  valid time, min and max:
#    INFO ->  valid time, min and max:
#    INFO ->  2019-01-01, 2019-12-01
#    INFO ->  2019-01-01, 2019-12-01
# Training with validation
# Training until validation scores don't improve for 150 rounds
# [100]	training's rmse: 0.46746	valid_1's rmse: 0.450219
# [200]	training's rmse: 0.355448	valid_1's rmse: 0.332579
# [300]	training's rmse: 0.304554	valid_1's rmse: 0.280262
# [400]	training's rmse: 0.273896	valid_1's rmse: 0.249224
# [500]	training's rmse: 0.252644	valid_1's rmse: 0.227384
# [600]	training's rmse: 0.236959	valid_1's rmse: 0.213401
# [700]	training's rmse: 0.221947	valid_1's rmse: 0.200653
# [800]	training's rmse: 0.209307	valid_1's rmse: 0.189011
# [900]	training's rmse: 0.200162	valid_1's rmse: 0.180137
# [1000]	training's rmse: 0.191447	valid_1's rmse: 0.172669
# [1100]	training's rmse: 0.183425	valid_1's rmse: 0.165441
# [1200]	training's rmse: 0.177091	valid_1's rmse: 0.159678
# [1300]	training's rmse: 0.171135	valid_1's rmse: 0.154688
# [1400]	training's rmse: 0.166095	valid_1's rmse: 0.149853
# [1500]	training's rmse: 0.161837	valid_1's rmse: 0.146067
# [1600]	training's rmse: 0.157845	valid_1's rmse: 0.141858
# [1700]	training's rmse: 0.154364	valid_1's rmse: 0.138932
# [1800]	training's rmse: 0.150899	valid_1's rmse: 0.136028
# [1900]	training's rmse: 0.147783	valid_1's rmse: 0.133426
# [2000]	training's rmse: 0.145231	valid_1's rmse: 0.131113
# [2100]	training's rmse: 0.142936	valid_1's rmse: 0.129081
# [2200]	training's rmse: 0.140274	valid_1's rmse: 0.12715
# [2300]	training's rmse: 0.138386	valid_1's rmse: 0.125309
# [2400]	training's rmse: 0.136373	valid_1's rmse: 0.123724
# [2500]	training's rmse: 0.134598	valid_1's rmse: 0.122298
# [2600]	training's rmse: 0.132913	valid_1's rmse: 0.120931
# [2700]	training's rmse: 0.131314	valid_1's rmse: 0.119744
# [2800]	training's rmse: 0.129871	valid_1's rmse: 0.118529
# [2900]	training's rmse: 0.128572	valid_1's rmse: 0.117693
# [3000]	training's rmse: 0.127319	valid_1's rmse: 0.116662
# [3100]	training's rmse: 0.126191	valid_1's rmse: 0.11577
# [3200]	training's rmse: 0.125013	valid_1's rmse: 0.114933
# [3300]	training's rmse: 0.123947	valid_1's rmse: 0.11423
# [3400]	training's rmse: 0.122954	valid_1's rmse: 0.11357
# [3500]	training's rmse: 0.122004	valid_1's rmse: 0.112975
# [3600]	training's rmse: 0.121087	valid_1's rmse: 0.112256
# [3700]	training's rmse: 0.120171	valid_1's rmse: 0.111779
# [3800]	training's rmse: 0.119337	valid_1's rmse: 0.111217
# [3900]	training's rmse: 0.118445	valid_1's rmse: 0.110627
# [4000]	training's rmse: 0.117652	valid_1's rmse: 0.110145
# [4100]	training's rmse: 0.11685	valid_1's rmse: 0.109669
# [4200]	training's rmse: 0.11612	valid_1's rmse: 0.109251
# [4300]	training's rmse: 0.115451	valid_1's rmse: 0.108794
# [4400]	training's rmse: 0.11477	valid_1's rmse: 0.108362
# [4500]	training's rmse: 0.11412	valid_1's rmse: 0.108008
# [4600]	training's rmse: 0.113408	valid_1's rmse: 0.107659
# [4700]	training's rmse: 0.112893	valid_1's rmse: 0.107325
# [4800]	training's rmse: 0.112248	valid_1's rmse: 0.106988
# [4900]	training's rmse: 0.111723	valid_1's rmse: 0.10665
# [5000]	training's rmse: 0.11115	valid_1's rmse: 0.106365
# [5100]	training's rmse: 0.110646	valid_1's rmse: 0.106056
# [5200]	training's rmse: 0.110091	valid_1's rmse: 0.105762
# [5300]	training's rmse: 0.109487	valid_1's rmse: 0.105501
# [5400]	training's rmse: 0.108964	valid_1's rmse: 0.105214
# [5500]	training's rmse: 0.108448	valid_1's rmse: 0.104969
# [5600]	training's rmse: 0.107971	valid_1's rmse: 0.104739
# [5700]	training's rmse: 0.107494	valid_1's rmse: 0.104533
# [5800]	training's rmse: 0.107046	valid_1's rmse: 0.104323
# [5900]	training's rmse: 0.106613	valid_1's rmse: 0.104087
# [6000]	training's rmse: 0.106151	valid_1's rmse: 0.103929
# [6100]	training's rmse: 0.105698	valid_1's rmse: 0.103745
# [6200]	training's rmse: 0.105283	valid_1's rmse: 0.103513
# [6300]	training's rmse: 0.104841	valid_1's rmse: 0.10333
# [6400]	training's rmse: 0.104404	valid_1's rmse: 0.10319
# [6500]	training's rmse: 0.104006	valid_1's rmse: 0.103041
# [6600]	training's rmse: 0.103619	valid_1's rmse: 0.102887
# [6700]	training's rmse: 0.103228	valid_1's rmse: 0.102725
# [6800]	training's rmse: 0.102856	valid_1's rmse: 0.102536
# [6900]	training's rmse: 0.102436	valid_1's rmse: 0.102385
# [7000]	training's rmse: 0.102097	valid_1's rmse: 0.102242
# [7100]	training's rmse: 0.101765	valid_1's rmse: 0.10211
# [7200]	training's rmse: 0.101427	valid_1's rmse: 0.101967
# [7300]	training's rmse: 0.101081	valid_1's rmse: 0.101819
# [7400]	training's rmse: 0.100704	valid_1's rmse: 0.101704
# [7500]	training's rmse: 0.100329	valid_1's rmse: 0.101557
# [7600]	training's rmse: 0.0999908	valid_1's rmse: 0.101439
# [7700]	training's rmse: 0.0996564	valid_1's rmse: 0.101324
# [7800]	training's rmse: 0.0993444	valid_1's rmse: 0.101214
# [7900]	training's rmse: 0.0990341	valid_1's rmse: 0.10111
# [8000]	training's rmse: 0.0986898	valid_1's rmse: 0.101025
# Did not meet early stopping. Best iteration is:
# [8000]	training's rmse: 0.0986898	valid_1's rmse: 0.101025
# MSE: 109.87396588763644
# Finished in 0:00:07.061863
# ReTraining on all data
# [100]	training's rmse: 0.458053
# [200]	training's rmse: 0.342468
# [300]	training's rmse: 0.289674
# [400]	training's rmse: 0.257608
# [500]	training's rmse: 0.235348
# [600]	training's rmse: 0.221031
# [700]	training's rmse: 0.206249
# [800]	training's rmse: 0.193424
# [900]	training's rmse: 0.18299
# [1000]	training's rmse: 0.175058
# [1100]	training's rmse: 0.167585
# [1200]	training's rmse: 0.16111
# [1300]	training's rmse: 0.155458
# [1400]	training's rmse: 0.149923
# [1500]	training's rmse: 0.14516
# [1600]	training's rmse: 0.141158
# [1700]	training's rmse: 0.137304
# [1800]	training's rmse: 0.133992
# [1900]	training's rmse: 0.131042
# [2000]	training's rmse: 0.128414
# [2100]	training's rmse: 0.12615
# [2200]	training's rmse: 0.123973
# [2300]	training's rmse: 0.121972
# [2400]	training's rmse: 0.120082
# [2500]	training's rmse: 0.118375
# [2600]	training's rmse: 0.116727
# [2700]	training's rmse: 0.11521
# [2800]	training's rmse: 0.113875
# [2900]	training's rmse: 0.112526
# [3000]	training's rmse: 0.111223
# [3100]	training's rmse: 0.11018
# [3200]	training's rmse: 0.108917
# [3300]	training's rmse: 0.10787
# [3400]	training's rmse: 0.10686
# [3500]	training's rmse: 0.105891
# [3600]	training's rmse: 0.105064
# [3700]	training's rmse: 0.104171
# [3800]	training's rmse: 0.103372
# [3900]	training's rmse: 0.102649
# [4000]	training's rmse: 0.101881
# [4100]	training's rmse: 0.101152
# [4200]	training's rmse: 0.10043
# [4300]	training's rmse: 0.0997087
# [4400]	training's rmse: 0.0990127
# [4500]	training's rmse: 0.0983866
# [4600]	training's rmse: 0.0977805
# [4700]	training's rmse: 0.0972409
# [4800]	training's rmse: 0.0966836
# [4900]	training's rmse: 0.0961708
# [5000]	training's rmse: 0.0956114
# [5100]	training's rmse: 0.0950868
# [5200]	training's rmse: 0.0945711
# [5300]	training's rmse: 0.0940759
# [5400]	training's rmse: 0.0935677
# [5500]	training's rmse: 0.0930875
# [5600]	training's rmse: 0.0926642
# [5700]	training's rmse: 0.0922055
# [5800]	training's rmse: 0.0917985
# [5900]	training's rmse: 0.0913943
# [6000]	training's rmse: 0.0909565
# [6100]	training's rmse: 0.0905376
# [6200]	training's rmse: 0.0901642
# [6300]	training's rmse: 0.0897713
# [6400]	training's rmse: 0.089365
# [6500]	training's rmse: 0.0890146
# [6600]	training's rmse: 0.0886714
# [6700]	training's rmse: 0.0883352
# [6800]	training's rmse: 0.0879839
# [6900]	training's rmse: 0.0876084
# [7000]	training's rmse: 0.0872682
# [7100]	training's rmse: 0.0869412
# [7200]	training's rmse: 0.0866097
# [7300]	training's rmse: 0.0862971
# [7400]	training's rmse: 0.0859976
# [7500]	training's rmse: 0.0856902
# [7600]	training's rmse: 0.0853813
# [7700]	training's rmse: 0.0851123
# [7800]	training's rmse: 0.0848236
# [7900]	training's rmse: 0.0845646
# [8000]	training's rmse: 0.0842421
# [8100]	training's rmse: 0.0839524
# [8200]	training's rmse: 0.083695
# [8300]	training's rmse: 0.0834244
# [8400]	training's rmse: 0.0831346
# [8500]	training's rmse: 0.0828912
# [8600]	training's rmse: 0.0826505
# [8700]	training's rmse: 0.082424
# [8800]	training's rmse: 0.0821628
# [8900]	training's rmse: 0.0819344
# [9000]	training's rmse: 0.0816848
# [9100]	training's rmse: 0.0814588
# [9200]	training's rmse: 0.0812446
#    INFO ->  feature importance
#    INFO ->  feature importance
#    INFO ->                                 feature  feature_importance
# 0                       cityid_encoder               11071
# 1                        carid_encoder               22374
# 2                           time_month                2108
# 3                      time_weekofyear                2972
# 4                       time_dayofweek                1829
# 5                         time_is_wknd                 111
# 6                         time_quarter                  87
# 7          cityid__carid__sales__lag_1               17500
# 8          cityid__carid__sales__lag_2                8395
# 9          cityid__carid__sales__lag_3                9359
# 10    cityid__carid__sales_roll_mean_4                3478
# 11    cityid__carid__sales_roll_mean_5                3720
# 12     cityid__carid__sales_roll_std_4                5446
# 13     cityid__carid__sales_roll_std_5                4497
# 14  cityid__carid__sales_roll_median_4               17578
# 15  cityid__carid__sales_roll_median_5                7263
# 16     cityid__carid__sales_roll_max_4                8653
# 17     cityid__carid__sales_roll_max_5                3356
# 18     cityid__carid__sales_roll_min_4                8812
# 19     cityid__carid__sales_roll_min_5                3690
# 20         cityid__carid__sales__ewm_1               15474
# 21         cityid__carid__sales__ewm_2                8666
# 22         cityid__carid__sales__ewm_3                9096
#    INFO ->                                 feature  feature_importance
# 0                       cityid_encoder               11071
# 1                        carid_encoder               22374
# 2                           time_month                2108
# 3                      time_weekofyear                2972
# 4                       time_dayofweek                1829
# 5                         time_is_wknd                 111
# 6                         time_quarter                  87
# 7          cityid__carid__sales__lag_1               17500
# 8          cityid__carid__sales__lag_2                8395
# 9          cityid__carid__sales__lag_3                9359
# 10    cityid__carid__sales_roll_mean_4                3478
# 11    cityid__carid__sales_roll_mean_5                3720
# 12     cityid__carid__sales_roll_std_4                5446
# 13     cityid__carid__sales_roll_std_5                4497
# 14  cityid__carid__sales_roll_median_4               17578
# 15  cityid__carid__sales_roll_median_5                7263
# 16     cityid__carid__sales_roll_max_4                8653
# 17     cityid__carid__sales_roll_max_5                3356
# 18     cityid__carid__sales_roll_min_4                8812
# 19     cityid__carid__sales_roll_min_5                3690
# 20         cityid__carid__sales__ewm_1               15474
# 21         cityid__carid__sales__ewm_2                8666
# 22         cityid__carid__sales__ewm_3                9096
#    INFO ->  start training xgboost model
#    INFO ->  start training xgboost model
#    INFO ->  (6912, 23)
#    INFO ->  (6912, 23)
#    INFO ->  log1p!
#    INFO ->  log1p!
#    INFO ->  train time, min and max:
#    INFO ->  train time, min and max:
#    INFO ->  2017-01-01, 2018-12-01
#    INFO ->  2017-01-01, 2018-12-01
#    INFO ->  valid time, min and max:
#    INFO ->  valid time, min and max:
#    INFO ->  2019-01-01, 2019-12-01
#    INFO ->  2019-01-01, 2019-12-01
# Finished in 0:00:08.042016
# Training with validation
# [14:52:22] WARNING: ../src/learner.cc:573:
# Parameters: { "metric", "verbose_eval" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [0]	validation_0-rmse:3.64423
# [100]	validation_0-rmse:1.43893
# [200]	validation_0-rmse:0.66449
# [300]	validation_0-rmse:0.43601
# [400]	validation_0-rmse:0.38136
# [500]	validation_0-rmse:0.36463
# [600]	validation_0-rmse:0.35638
# [700]	validation_0-rmse:0.34985
# [800]	validation_0-rmse:0.34437
# [900]	validation_0-rmse:0.34039
# [1000]	validation_0-rmse:0.33670
# [1100]	validation_0-rmse:0.33366
# [1200]	validation_0-rmse:0.33126
# [1300]	validation_0-rmse:0.32887
# [1400]	validation_0-rmse:0.32672
# [1500]	validation_0-rmse:0.32481
# [1600]	validation_0-rmse:0.32315
# [1700]	validation_0-rmse:0.32155
# [1800]	validation_0-rmse:0.32055
# [1900]	validation_0-rmse:0.31945
# [2000]	validation_0-rmse:0.31843
# [2100]	validation_0-rmse:0.31758
# [2200]	validation_0-rmse:0.31702
# [2300]	validation_0-rmse:0.31633
# [2400]	validation_0-rmse:0.31554
# [2500]	validation_0-rmse:0.31495
# [2600]	validation_0-rmse:0.31442
# [2700]	validation_0-rmse:0.31402
# [2800]	validation_0-rmse:0.31360
# [2900]	validation_0-rmse:0.31308
# [2999]	validation_0-rmse:0.31267
# MSE: 823.146740503631
# Finished in 0:00:17.459343
# ReTraining on all data
# [14:52:39] WARNING: ../src/learner.cc:573:
# Parameters: { "metric", "verbose_eval" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [0]	validation_0-rmse:3.66159
# [100]	validation_0-rmse:1.44396
# [200]	validation_0-rmse:0.67715
# [300]	validation_0-rmse:0.45848
# [400]	validation_0-rmse:0.40450
# [500]	validation_0-rmse:0.38204
# [600]	validation_0-rmse:0.36563
# [700]	validation_0-rmse:0.35417
# [800]	validation_0-rmse:0.34498
# [900]	validation_0-rmse:0.33768
# [1000]	validation_0-rmse:0.33157
# [1100]	validation_0-rmse:0.32625
# [1200]	validation_0-rmse:0.32151
# [1300]	validation_0-rmse:0.31746
# [1400]	validation_0-rmse:0.31389
# [1500]	validation_0-rmse:0.31042
# [1600]	validation_0-rmse:0.30736
# [1700]	validation_0-rmse:0.30470
# [1800]	validation_0-rmse:0.30245
# [1900]	validation_0-rmse:0.29988
# [2000]	validation_0-rmse:0.29792
# [2100]	validation_0-rmse:0.29611
# [2200]	validation_0-rmse:0.29447
# [2300]	validation_0-rmse:0.29274
# [2400]	validation_0-rmse:0.29121
# [2500]	validation_0-rmse:0.29001
# [2600]	validation_0-rmse:0.28862
# [2700]	validation_0-rmse:0.28734
# [2800]	validation_0-rmse:0.28628
# [2900]	validation_0-rmse:0.28528
# [3000]	validation_0-rmse:0.28441
# [3100]	validation_0-rmse:0.28376
# [3200]	validation_0-rmse:0.28301
# [3300]	validation_0-rmse:0.28228
# [3400]	validation_0-rmse:0.28174
# [3447]	validation_0-rmse:0.28149
# Finished in 0:00:30.675941

# %%
sub
# Out:
#       cityid  carid        time       sales
# 0          0      1  2020-01-01  234.294395
# 1          0      1  2020-02-01   50.390168
# 2          0      1  2020-03-01   75.705420
# 3          0      1  2020-04-01   93.954961
# 4          0      1  2020-05-01   93.716868
# ...      ...    ...         ...         ...
# 2299       5     32  2020-08-01   44.777272
# 2300       5     32  2020-09-01   44.892431
# 2301       5     32  2020-10-01   44.870242
# 2302       5     32  2020-11-01   44.690566
# 2303       5     32  2020-12-01   44.842880
#
# [2304 rows x 4 columns]
