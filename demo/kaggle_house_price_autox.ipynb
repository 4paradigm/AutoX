# %% [markdown]
# ## 导入所需的包

# %%
# !git log
# Out:
# commit 89611b6d10d4492cde5b6f390d2c4077977b66f1 (HEAD -> master, origin/master, origin/HEAD)
# Author: poteman <946691288@qq.com>
# Date:   Fri Aug 27 15:52:55 2021 +0800
#
#     xgb打印轮次设置为100
#
# commit 984d81a49150edd80d177137ceb748591db1a04d
# Author: poteman <946691288@qq.com>
# Date:   Fri Aug 27 15:42:14 2021 +0800
#
#     回归模型调参,修改验证集切分方式.
#
# commit 7fb12ebf09d04b0a617896ab1a63474fc8bb55a5
# Author: poteman <946691288@qq.com>
# Date:   Fri Aug 27 15:09:13 2021 +0800
#
#     优化特征类型识别.
#
# commit 39f94e1e4cd82c6d148556d80bb47146bfc8d539
# Author: poteman <946691288@qq.com>
# Date:   Fri Aug 27 14:58:53 2021 +0800
#
#     优化特征类型识别.
#
# commit 9f78099656c32f335a9134ea6358f131891699f0
# Author: poteman <946691288@qq.com>
# Date:   Thu Aug 26 17:02:52 2021 +0800
#
#     modify readme.
#
# commit 656c91218b289fe61cf21855e16b6895acec2c78
# Author: poteman <946691288@qq.com>
# Date:   Tue Aug 24 15:21:30 2021 +0800
#
#     优化readme,增加zhidemai比赛上分点总结
#
# ...

# %%
from autox import AutoX
import pandas as pd
import numpy as np
import os
from tqdm import tqdm

# %% [markdown]
# ## 配置数据信息

# %%
# 选择数据集
data_name = 'kaggle_house_price'
path = f'./data/{data_name}'

# %%
autox = AutoX(target = 'SalePrice', train_name = 'train.csv', test_name = 'test.csv', 
               id = ['Id'], path = path)
# Out:
#    INFO ->  [+] read sample_submission.csv
#    INFO ->  Memory usage of dataframe is 0.02 MB
#    INFO ->  Memory usage after optimization is: 0.01 MB
#    INFO ->  Decreased by 62.2%
#    INFO ->  table = sample_submission.csv, shape = (1459, 2)
#    INFO ->  [+] read train.csv
#    INFO ->  Memory usage of dataframe is 0.90 MB
#    INFO ->  Memory usage after optimization is: 0.16 MB
#    INFO ->  Decreased by 81.7%
#    INFO ->  table = train.csv, shape = (1460, 81)
#    INFO ->  [+] read test.csv
#    INFO ->  Memory usage of dataframe is 0.89 MB
#    INFO ->  Memory usage after optimization is: 0.16 MB
#    INFO ->  Decreased by 81.7%
#    INFO ->  table = test.csv, shape = (1459, 80)

# %%
sub = autox.get_submit()
# Out:
#    INFO ->  start feature engineer
#    INFO ->  feature engineer: Stat
# 100%|██████████| 43/43 [00:18<00:00,  2.29it/s]
# ...

# %%
sub_ens.to_csv("autox_0827_kaggle_house_price.csv", index = False)
