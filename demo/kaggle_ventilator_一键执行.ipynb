# %% [markdown]
# ## 导入所需的包

# %%
# !git log
# Out:
# commit db903d295e59e38c749ac45381347561caf40545 (HEAD -> master, origin/master, origin/HEAD)
# Author: poteman <946691288@qq.com>
# Date:   Fri Sep 24 17:18:50 2021 +0800
#
#     init FeatureDenoisingAutoencoder.
#
# commit 08cc35212f2e0d463724cc6b27597253f1329105
# Author: poteman <946691288@qq.com>
# Date:   Fri Sep 24 17:13:57 2021 +0800
#
#     denoising autoencoder特征.
#
# commit 410ef74d5756873d890caa07274b8ee0e1d746c5
# Author: poteman <946691288@qq.com>
# Date:   Thu Sep 23 16:58:48 2021 +0800
#
#     modify README.md; add stumbleupon demo.
#
# commit 755a5bc45c760238e6e4309f1985959a4c5364b1
# Author: poteman <946691288@qq.com>
# Date:   Wed Sep 22 11:37:03 2021 +0800
#
#     全流程中加入nlp特征; 增加stumbleupon的demo.
#
# commit 4d39f318551660fe139878a5c88db1d3aaac0b97
# Author: poteman <946691288@qq.com>
# Date:   Fri Sep 17 20:53:19 2021 +0800
#
#     一键执行逻辑中增加nlp特征.
#
# commit 55f67716c7a50366d45249c0f9d3ea4166c13c41
# Author: poteman <946691288@qq.com>
# ...

# %%
from autox import AutoX
import pandas as pd
import numpy as np
import os
from tqdm import tqdm

# %% [markdown]
# ## 配置数据信息

# %%
# 选择数据集
data_name = 'ventilator'
path = f'./data/{data_name}'

# %%
autox = AutoX(target = 'pressure', train_name = 'train.csv', test_name = 'test.csv', 
               id = ['id'], path = path)
# Out:
#    INFO ->  [+] read sample_submission.csv
#    INFO ->  Memory usage of dataframe is 61.40 MB
#    INFO ->  Memory usage after optimization is: 19.19 MB
#    INFO ->  Decreased by 68.7%
#    INFO ->  table = sample_submission.csv, shape = (4024000, 2)
#    INFO ->  [+] read train.csv
#    INFO ->  Memory usage of dataframe is 368.41 MB
#    INFO ->  Memory usage after optimization is: 97.86 MB
#    INFO ->  Decreased by 73.4%
#    INFO ->  table = train.csv, shape = (6036000, 8)
#    INFO ->  [+] read test.csv
#    INFO ->  Memory usage of dataframe is 214.90 MB
#    INFO ->  Memory usage after optimization is: 57.56 MB
#    INFO ->  Decreased by 73.2%
#    INFO ->  table = test.csv, shape = (4024000, 7)

# %%
sub = autox.get_submit()
# Out:
#    INFO ->  start feature engineer
#    INFO ->  feature engineer: Stat
# 0it [00:00, ?it/s]
#    INFO ->  featureStat ops: {}
#    INFO ->  feature engineer: NLP
# 0it [00:00, ?it/s]
#    INFO ->  featureNlp ops: []
#    INFO ->  feature engineer: Count
# 0it [00:00, ?it/s]
#    INFO ->  featureCount ops: []
#    INFO ->  feature engineer: Rank
# 0it [00:00, ?it/s]
#    INFO ->  featureRank ops: {}
# 100%|██████████| 8/8 [00:00<00:00, 27458.62it/s]
#    INFO ->  label_encoder_list: []
#    INFO ->  feature combination
#    INFO ->  shape of FE_all: (10060000, 8), shape of train: (6036000, 8), shape of test: (4024000, 8)
#    INFO ->  feature filter
# 100%|██████████| 8/8 [00:00<00:00,  8.41it/s]
#    INFO ->  filtered features: ['id', 'pressure']
#    INFO ->  used_features: ['breath_id', 'R', 'C', 'time_step', 'u_in', 'u_out']
#    INFO ->  start training model
#    INFO ->  (6036000, 6)
#    INFO ->  [+]tuning params
# ...

# %%
sub.to_csv("autox_0927_kaggle_ventilator_一键执行.csv", index = False)

# %%
# !zip -r autox_0927_kaggle_ventilator_一键执行.csv.zip autox_0927_kaggle_ventilator_一键执行.csv
# Out:
#   adding: autox_0927_kaggle_ventilator_一键执行.csv (deflated 59%)
