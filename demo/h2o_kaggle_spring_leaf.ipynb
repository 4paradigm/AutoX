# %%
import pandas as pd
import numpy as np
import os

# %%
import h2o
from h2o.automl import H2OAutoML
h2o.init()
# Out:
# Checking whether there is an H2O instance running at http://localhost:54321 . connected.
# --------------------------  ------------------------------------------------------------------
# H2O_cluster_uptime:         14 mins 16 secs
# H2O_cluster_timezone:       Asia/Shanghai
# H2O_data_parsing_timezone:  UTC
# H2O_cluster_version:        3.32.1.5
# H2O_cluster_version_age:    1 month and 2 days
# H2O_cluster_name:           H2O_from_python_caihengxing_5p2i4b
# H2O_cluster_total_nodes:    1
# H2O_cluster_free_memory:    26.66 Gb
# H2O_cluster_total_cores:    40
# H2O_cluster_allowed_cores:  40
# H2O_cluster_status:         locked, healthy
# H2O_connection_url:         http://localhost:54321
# H2O_connection_proxy:       {"http": null, "https": null}
# H2O_internal_security:      False
# H2O_API_Extensions:         Amazon S3, XGBoost, Algos, AutoML, Core V3, TargetEncoder, Core V4
# Python_version:             3.7.3 final
# --------------------------  ------------------------------------------------------------------

# %%
data_name = 'kaggle_springleaf'

# %%
train_path = f'../autox/data/{data_name}/train.csv'
test_path = f'../autox/data/{data_name}/test.csv'

# %%
# Load data into H2O
train = h2o.import_file(train_path)
test  = h2o.import_file(test_path)
# Out:
# Parse progress: |█████████████████████████████████████████████████████████| 100%
# Parse progress: |█████████████████████████████████████████████████████████| 100%

# %%
train.head()
# Out:
# <table>
# <thead>
# <tr><th style="text-align: right;">  ID</th><th>VAR_0001  </th><th style="text-align: right;">  VAR_0002</th><th style="text-align: right;">  VAR_0003</th><th style="text-align: right;">  VAR_0004</th><th>VAR_0005  </th><th style="text-align: right;">  VAR_0006</th><th style="text-align: right;">  VAR_0007</th><th>VAR_0008  </th><th>VAR_0009  </th><th>VAR_0010  </th><th>VAR_0011  </th><th>VAR_0012  </th><th style="text-align: right;">  VAR_0013</th><th style="text-align: right;">  VAR_0014</th><th style="text-align: right;">  VAR_0015</th><th style="text-align: right;">  VAR_0016</th><th style="text-align: right;">  VAR_0017</th><th style="text-align: right;">  VAR_0018</th><th style="text-align: right;">  VAR_0019</th><th style="text-align: right;">  VAR_0020</th><th style="text-align: right;">  VAR_0021</th><th style="text-align: right;">  VAR_0022</th><th style="text-align: right;">  VAR_0023</th><th style="text-align: right;">  VAR_0024</th><th style="text-align: right;">  VAR_0025</th><th style="text-align: right;">  VAR_0026</th><th style="text-align: right;">  VAR_0027</th><th style="text-align: right;">  VAR_0028</th><th style="text-align: right;">  VAR_0029</th><th style="text-align: right;">  VAR_0030</th><th style="text-align: right;">  VAR_0031</th><th style="text-align: right;">  VAR_0032</th><th style="text-align: right;">  VAR_0033</th><th style="text-align: right;">  VAR_0034</th><th style="text-align: right;">  VAR_0035</th><th style="text-align: right;">  VAR_0036</th><th style="text-align: right;">  VAR_0037</th><th style="text-align: right;">  VAR_0038</th><th style="text-align: right;">  VAR_0039</th><th style="text-align: right;">  VAR_0040</th><th style="text-align: right;">  VAR_0041</th><th style="text-align: right;">  VAR_0042</th><th>VAR_0043  </th><th>VAR_0044  </th><th style="text-align: right;">  VAR_0045</th><th style="text-align: right;">  VAR_0046</th><th style="text-align: right;">  VAR_0047</th><th style="text-align: right;">  VAR_0048</th><th style="text-align: right;">  VAR_0049</th><th style="text-align: right;">  VAR_0050</th><th style="text-align: right;">  VAR_0051</th><th style="text-align: right;">  VAR_0052</th><th style="text-align: right;">  VAR_0053</th><th style="text-align: right;">  VAR_0054</th><th style="text-align: right;">  VAR_0055</th><th style="text-align: right;">  VAR_0056</th><th style="text-align: right;">  VAR_0057</th><th style="text-align: right;">  VAR_0058</th><th style="text-align: right;">  VAR_0059</th><th style="text-align: right;">  VAR_0060</th><th style="text-align: right;">  VAR_0061</th><th style="text-align: right;">  VAR_0062</th><th style="text-align: right;">  VAR_0063</th><th style="text-align: right;">  VAR_0064</th><th style="text-align: right;">  VAR_0065</th><th style="text-align: right;">  VAR_0066</th><th style="text-align: right;">  VAR_0067</th><th style="text-align: right;">  VAR_0068</th><th style="text-align: right;">  VAR_0069</th><th style="text-align: right;">  VAR_0070</th><th style="text-align: right;">  VAR_0071</th><th style="text-align: right;">  VAR_0072</th><th>VAR_0073           </th><th style="text-align: right;">  VAR_0074</th><th>VAR_0075           </th><th style="text-align: right;">  VAR_0076</th><th style="text-align: right;">  VAR_0077</th><th style="text-align: right;">  VAR_0078</th><th style="text-align: right;">  VAR_0079</th><th style="text-align: right;">  VAR_0080</th><th style="text-align: right;">  VAR_0081</th><th style="text-align: right;">  VAR_0082</th><th style="text-align: right;">  VAR_0083</th><th style="text-align: right;">  VAR_0084</th><th style="text-align: right;">  VAR_0085</th><th style="text-align: right;">  VAR_0086</th><th style="text-align: right;">  VAR_0087</th><th style="text-align: right;">  VAR_0088</th><th style="text-align: right;">  VAR_0089</th><th style="text-align: right;">  VAR_0090</th><th style="text-align: right;">  VAR_0091</th><th style="text-align: right;">  VAR_0092</th><th ...

# %%
Id = "ID"
y = "target"

# %%
aml2 = H2OAutoML(max_runtime_secs = 7200, seed = 1, project_name = data_name)
aml2.train(y = y, training_frame = train)
# Out:
# AutoML progress: |█████████████████████████████████████
# 16:07:32.606: XRT_1_AutoML_20210907_152929 [DRF XRT (Extremely Randomized Trees)] failed: java.lang.AssertionError
#
# ███████████████████| 100%

# %%
pred = aml2.predict(test)
# Out:
# stackedensemble prediction progress: |████████████████████████████████████| 100%
# /home/caihengxing/anaconda3/lib/python3.7/site-packages/h2o/job.py:72: UserWarning: Test/Validation dataset column 'VAR_0200' has levels not trained on: ["08620", "2 WHITE OAK", "20 BRUNSWICK", "23453", "24279", "29 PALMS", "3 JASPER", "35010", "36609", "38683", ...4177 not listed..., "YOUINGSTOWN", "YUCAIP", "ZANESFIELD", "ZEPHRYRHILLS", "ZEPHY", "ZEPHYHILLS", "ZION CROSSROADS", "ZION GROVE", "ZOLFO SPRINGS", "ZWOLLE"]
#   warnings.warn(w)
# /home/caihengxing/anaconda3/lib/python3.7/site-packages/h2o/job.py:72: UserWarning: Test/Validation dataset column 'VAR_0214' has levels not trained on: ["FSI-0003-1", "HRE-Home Phone-4717", "HRE-Social Security Number-1011", "HRE-Social Security Number-10887", "HRE-Social Security Number-1231", "HRE-Social Security Number-13457", "HRE-Social Security Number-14395", "HRE-Social Security Number-1453", "HRE-Social Security Number-15467", "HRE-Social Security Number-18087", "HRE-Social Security Number-20083", "HRE-Social Security Number-2801", "HRE-Social Security Number-9871"]
#   warnings.warn(w)
# /home/caihengxing/anaconda3/lib/python3.7/site-packages/h2o/job.py:72: UserWarning: Test/Validation dataset column 'VAR_0237' has levels not trained on: ["ND"]
#   warnings.warn(w)
# /home/caihengxing/anaconda3/lib/python3.7/site-packages/h2o/job.py:72: UserWarning: Test/Validation dataset column 'VAR_0283' has levels not trained on: ["G"]
#   warnings.warn(w)

# %%
sub = pd.read_csv(test_path)
sub = sub[[Id]]
# Out:
# /home/caihengxing/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3057: DtypeWarning: Columns (8,9,10,11,12,43,157,167,177,196,214,225,228,229,231,235,238) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
pred = h2o.as_list(pred)

# %%
sub[y] = pred['predict']

# %%
sub['target'] = sub['target'].clip(0,1)

# %%
sub.to_csv(f"./h2o_sub_{data_name}.csv", index = False)
