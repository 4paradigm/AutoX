# %%
from autox import AutoXServer
# Out:
# /home/caihengxing/anaconda3/lib/python3.7/site-packages/pandas/compat/_optional.py:138: UserWarning: Pandas requires version '2.7.0' or newer of 'numexpr' (version '2.6.9' currently installed).
#   warnings.warn(msg, UserWarning)

# %%
data_info_path = './bank/data_info.json'
train_set_path = './bank/train_data'

# %%
autoxserver = AutoXServer(is_train = True, server_name = 'bank',
                          data_info_path = data_info_path, train_set_path = train_set_path)
autoxserver.fit()
# Out:
#    INFO ->  data name: bank
#    INFO ->  data name: bank
#    INFO ->  *** phase: train
#    INFO ->  *** phase: train
#    INFO ->  read data_info.json
#    INFO ->  read data_info.json
#    INFO ->  data_info: {'dataset_id': 'Athena', 'recom_metrics': ['auc'], 'target_entity': 'overdue', 'target_id': ['new_user_id'], 'target_label': 'label', 'time_budget': 7200, 'target_time': 'flag1', 'time_series_data': 'true', 'entities': {'overdue': {'file_name': 'overdue.csv', 'format': 'csv', 'header': 'true', 'is_static': 'true', 'time_col': [], 'columns': [{'new_user_id': 'Str'}, {'label': 'Num'}, {'flag1': 'Unix_timestamp'}]}, 'userinfo': {'file_name': 'userinfo.csv', 'format': 'csv', 'header': 'true', 'is_static': 'true', 'time_col': [], 'columns': [{'new_user_id': 'Str'}, {'flag1': 'Unix_timestamp'}, {'flag2': 'Num'}, {'flag3': 'Num'}, {'flag4': 'Num'}, {'flag5': 'Num'}]}, 'bank': {'file_name': 'bank.csv', 'format': 'csv', 'header': 'true', 'is_static': 'false', 'time_col': ['flag1'], 'columns': [{'new_user_id': 'Str'}, {'flag1': 'Unix_timestamp'}, {'flag2': 'Num'}, {'flag3': 'Num'}, {'flag4': 'Num'}]}, 'browse': {'file_name': 'browse.csv', 'format': 'csv', 'header': 'true', 'is_static': 'false', 'time_col': ['flag1'], 'columns': [{'new_user_id': 'Str'}, {'flag1': 'Unix_timestamp'}, {'flag2': 'Num'}, {'flag3': 'Num'}]}, 'bill': {'file_name': 'bill.csv', 'format': 'csv', 'header': 'true', 'is_static': 'false', 'time_col': ['flag1'], 'columns': [{'new_user_id': 'Str'}, {'flag1': 'Unix_timestamp'}, {'flag2': 'Num'}, {'flag3': 'Num'}, {'flag4': 'Num'}, {'flag5': 'Num'}, {'flag6': 'Num'}, {'flag7': 'Num'}, {'flag8': 'Num'}, {'flag9': 'Num'}, {'flag10': 'Num'}, {'flag11': 'Num'}, {'flag12': 'Num'}, {'flag13': 'Num'}, {'flag14': 'Num'}]}}, 'relations': [{'related_to_main_table': 'true', 'left_entity': 'overdue', 'left_on': ['new_user_id'], 'right_entity': 'userinfo', 'right_on': ['new_user_id'], 'type': '1-1'}, {'related_to_main_table': 'true', 'left_entity': 'overdue', 'left_on': ['new_user_id'], 'left_time_col': 'flag1', 'right_entity': 'bank', 'right_on': ['new_user_id'], 'right_time_col': 'flag1', 'type': '1-M'}, {'related_to_main_table': 'true', 'left_entity': 'overdue', 'left_on': ['new_user_id'], 'left_time_col': 'flag1', 'right_entity': 'browse', 'right_on': ['new_user_id'], 'right_time_col': 'flag1', 'type': '1-M'}, {'related_to_main_table': 'true', 'left_entity': 'overdue', 'left_on': ['new_user_id'], 'left_time_col': 'flag1', 'right_entity': 'bill', 'right_on': ['new_user_id'], 'right_time_col': 'flag1', 'type': '1-M'}]}
#    INFO ->  data_info: {'dataset_id': 'Athena', 'recom_metrics': ['auc'], 'target_entity': 'overdue', 'target_id': ['new_user_id'], 'target_label': 'label', 'time_budget': 7200, 'target_time': 'flag1', 'time_series_data': 'true', 'entities': {'overdue': {'file_name': 'overdue.csv', 'format': 'csv', 'header': 'true', 'is_static': 'true', 'time_col': [], 'columns': [{'new_user_id': 'Str'}, {'label': 'Num'}, {'flag1': 'Unix_timestamp'}]}, 'userinfo': {'file_name': 'userinfo.csv', 'format': 'csv', 'header': 'true', 'is_static': 'true', 'time_col': [], 'columns': [{'new_user_id': 'Str'}, {'flag1': 'Unix_timestamp'}, {'flag2': 'Num'}, {'flag3': 'Num'}, {'flag4': 'Num'}, {'flag5': 'Num'}]}, 'bank': {'file_name': 'bank.csv', 'format': 'csv', 'header': 'true', 'is_static': 'false', 'time_col': ['flag1'], 'columns': [{'new_user_id': 'Str'}, {'flag1': 'Unix_timestamp'}, {'flag2': 'Num'}, {'flag3': 'Num'}, {'flag4': 'Num'}]}, 'browse': {'file_name': 'browse.csv', 'format': 'csv', 'header': 'true', 'is_static': 'false', 'time_col': ['flag1'], 'columns': [{'new_user_id': 'Str'}, {'flag1': 'Unix_timestamp'}, {'flag2': 'Num'}, {'flag3': 'Num'}]}, 'bill': {'file_name': 'bill.csv', 'format': 'csv', 'header': 'true', 'is_static': 'false', 'time_col': ['flag1'], 'columns': [{'new_user_id': 'Str'}, {'flag1': 'Unix_timestamp'}, {'flag2': 'Num'}, {'flag3': 'Num'}, {'flag4': 'Num'}, {'flag5': 'Num'}, {'flag6': 'Num'}, {'flag7': 'Num'}, {'flag8': 'Num'}, {'flag9': 'Num'}, {'flag10': 'Num'}, {'flag11': 'Num'}, {'flag12': 'Num'}, {'flag13': 'Num'}, {'flag14': 'Num'}]}}, 'relations': [{'related_to_main_table': 'true', 'left_entity': 'overdue', 'left_on': ['new_user_id'], 'right_entity': 'userinfo', 'right_on': ['new_user_id'], 'type': '1-1'}, {'related_to_main_table': 'true', 'left_entity': 'overdue', 'left_on': ['new_user_id'], 'left_time_col': 'flag1', 'right_entity': 'bank', 'right_on': ['new_user_id'], 'right_time_col': 'flag1', 'type': '1-M'}, {'related_to_main_table': 'true', 'left_entity': 'overdue', 'left_on': ['new_user_id'], 'left_time_col': 'flag1', 'right_entity': 'browse', 'right_on': ['new_user_id'], 'right_time_col': 'flag1', 'type': '1-M'}, {'related_to_main_table': 'true', 'left_entity': 'overdue', 'left_on': ['new_user_id'], 'left_time_col': 'flag1', 'right_entity': 'bill', 'right_on': ['new_user_id'], 'right_time_col': 'flag1', 'type': '1-M'}]}
#    INFO ->  [+] read overdue_train.csv
#    INFO ->  [+] read overdue_train.csv
#    INFO ->  key = overdue, shape = (35831, 4)
#    INFO ->  key = overdue, shape = (35831, 4)
#    INFO ->  [+] read userinfo_train.csv
#    INFO ->  [+] read userinfo_train.csv
#    INFO ->  key = userinfo, shape = (35831, 6)
#    INFO ->  key = userinfo, shape = (35831, 6)
#    INFO ->  [+] read bank_train.csv
#    INFO ->  [+] read bank_train.csv
#    INFO ->  key = bank, shape = (4479878, 5)
#    INFO ->  key = bank, shape = (4479878, 5)
#    INFO ->  [+] read browse_train.csv
#    INFO ->  [+] read browse_train.csv
#    INFO ->  key = browse, shape = (14648563, 4)
#    INFO ->  key = browse, shape = (14648563, 4)
#    INFO ->  [+] read bill_train.csv
#    INFO ->  [+] read bill_train.csv
#    INFO ->  key = bill, shape = (1528927, 15)
#    INFO ->  key = bill, shape = (1528927, 15)
#    INFO ->  remain_time: 7186.8321805000305 s
#    INFO ->  remain_time: 7186.8321805000305 s
#    INFO ->  [+] preprocess, delete_row
#    INFO ->  [+] preprocess, delete_row
#    INFO ->  drop_rows_idx:[]
#    INFO ->  drop_rows_idx:[]
#    INFO ->  [+] preprocess, parsing_time
#    INFO ->  [+] preprocess, parsing_time
#    INFO ->  {}
#    INFO ->  {}
#    INFO ->  time columns: {}
#    INFO ->  time columns: {}
#    INFO ->  remain_time: 7186.8186638355255 s
#    INFO ->  remain_time: 7186.8186638355255 s
#    INFO ->  [+] join simple tables
#    INFO ->  [+] join simple tables
#    INFO ->  userinfo
#    INFO ->  userinfo
#    INFO ->  remain_time: 7186.7848744392395 s
#    INFO ->  remain_time: 7186.7848744392395 s
#    INFO ->  [+] preprocess_2
#    INFO ->  [+] preprocess_2
#    INFO ->  [+] preprocess_2: del invalid features
#    INFO ->  [+] preprocess_2: del invalid features
#    INFO ->  delete column: {}
#    INFO ->  delete column: {}
#    INFO ->  remain_time: 7186.770089626312 s
#    INFO ->  remain_time: 7186.770089626312 s
#    INFO ->  [+] join indirect 1_to_M tables
#    INFO ->  [+] join indirect 1_to_M tables
#    INFO ->  remain_time: 7186.770082235336 s
#    INFO ->  remain_time: 7186.770082235336 s
#    INFO ->  [+] preprocess_after_join_indirect_tables
#    INFO ->  [+] preprocess_after_join_indirect_tables
#    INFO ->  [+] preprocess_after_join_indirect_tables: rename columns
#    INFO ->  [+] preprocess_after_join_indirect_tables: rename columns
#    INFO ->  remain_time: 7186.768231153488 s
#    INFO ->  remain_time: 7186.768231153488 s
#    INFO ->  [+] join 1_to_M tables
#    INFO ->  [+] join 1_to_M tables
#    INFO ->  process table : bank
#    INFO ->  process table : bank
#    INFO ->  process table : browse
#    INFO ->  process table : browse
#    INFO ->  process table : bill
#    INFO ->  process table : bill
#    INFO ->  remain_time: 7153.62833404541 s
#    INFO ->  remain_time: 7153.62833404541 s
#    INFO ->  [+] preprocess_3
#    INFO ->  [+] preprocess_3
#    INFO ->  [+] preprocess_3: rename columns
#    INFO ->  [+] preprocess_3: rename columns
#    INFO ->  [+] preprocess_3: del invalid features
#    INFO ->  [+] preprocess_3: del invalid features
#    INFO ->  delete column: ['bank_flag4__min', 'bank_flag4__median', 'bill_flag14__min']
#    INFO ->  delete column: ['bank_flag4__min', 'bank_flag4__median', 'bill_flag14__min']
#    INFO ->  [+] preprocess_3: process multi_value features
#    INFO ->  [+] preprocess_3: process multi_value features
# 0it [00:00, ?it/s]
#    INFO ->  [+] preprocess_3: label encoding
#    INFO ->  [+] preprocess_3: label encoding
#    INFO ->  remain_time: 7153.442306756973 s
#    INFO ->  remain_time: 7153.442306756973 s
#    INFO ->  [+] base_lgb lightgbm
#    INFO ->  [+] base_lgb lightgbm
#    INFO ->  train.shape: (35831, 111)
#    INFO ->  train.shape: (35831, 111)
#    INFO ->  train[used_features].shape: (35831, 108)
#    INFO ->  train[used_features].shape: (35831, 108)
#    INFO ->  split data with time
#    INFO ->  split data with time
#    INFO ->  use time series index
#    INFO ->  use time series index
#    INFO ->  28905 for train, 6926 for valid
#    INFO ->  28905 for train, 6926 for valid
#    INFO ->  [+] Pre training for estimate time
#    INFO ->  [+] Pre training for estimate time
#    INFO ->  estimate time: 90.29513597488403
#    INFO ->  estimate time: 90.29513597488403
#    INFO ->  [+] Formal training
#    INFO ->  [+] Formal training
# Training until validation scores don't improve for 200 rounds
# Did not meet early stopping. Best iteration is:
# [10]	training's auc: 0.759157	valid_1's auc: 0.656721
# Training until validation scores don't improve for 200 rounds
# [20]	training's auc: 0.767075	valid_1's auc: 0.660453
# [40]	training's auc: 0.775653	valid_1's auc: 0.662762
# [60]	training's auc: 0.781959	valid_1's auc: 0.666735
# [80]	training's auc: 0.789956	valid_1's auc: 0.668075
# [100]	training's auc: 0.796783	valid_1's auc: 0.66879
# [120]	training's auc: 0.802392	valid_1's auc: 0.671436
# [140]	training's auc: 0.808669	valid_1's auc: 0.672589
# [160]	training's auc: 0.814185	valid_1's auc: 0.673169
# [180]	training's auc: 0.819183	valid_1's auc: 0.674239
# [200]	training's auc: 0.824508	valid_1's auc: 0.674351
# [220]	training's auc: 0.829584	valid_1's auc: 0.675045
# [240]	training's auc: 0.835224	valid_1's auc: 0.676011
# [260]	training's auc: 0.839982	valid_1's auc: 0.676391
# [280]	training's auc: 0.845004	valid_1's auc: 0.677245
# [300]	training's auc: 0.849455	valid_1's auc: 0.678096
# [320]	training's auc: 0.854001	valid_1's auc: 0.678283
# [340]	training's auc: 0.858391	valid_1's auc: 0.67877
# [360]	training's auc: 0.86241	valid_1's auc: 0.679254
# [380]	training's auc: 0.866517	valid_1's auc: 0.679821
# [400]	training's auc: 0.870232	valid_1's auc: 0.679983
# [420]	training's auc: 0.873968	valid_1's auc: 0.680355
# [440]	training's auc: 0.877464	valid_1's auc: 0.680735
# [460]	training's auc: 0.881054	valid_1's auc: 0.681485
# [480]	training's auc: 0.884395	valid_1's auc: 0.682113
# [500]	training's auc: 0.887649	valid_1's auc: 0.682616
# [520]	training's auc: 0.890713	valid_1's auc: 0.682856
# [540]	training's auc: 0.893552	valid_1's auc: 0.683307
# [560]	training's auc: 0.896741	valid_1's auc: 0.683624
# [580]	training's auc: 0.899609	valid_1's auc: 0.683823
# [600]	training's auc: 0.902351	valid_1's auc: 0.684042
# [620]	training's auc: 0.904909	valid_1's auc: 0.683965
# [640]	training's auc: 0.907515	valid_1's auc: 0.684016
# [660]	training's auc: 0.909928	valid_1's auc: 0.68438
# [680]	training's auc: 0.912079	valid_1's auc: 0.68453
# [700]	training's auc: 0.914231	valid_1's auc: 0.684565
# [720]	training's auc: 0.916318	valid_1's auc: 0.684794
# [740]	training's auc: 0.918415	valid_1's auc: 0.684861
# [760]	training's auc: 0.92048	valid_1's auc: 0.684672
# [780]	training's auc: 0.922477	valid_1's auc: 0.684803
# [800]	training's auc: 0.924301	valid_1's auc: 0.684891
# [820]	training's auc: 0.926077	valid_1's auc: 0.684967
# [840]	training's auc: 0.927905	valid_1's auc: 0.684963
# [860]	training's auc: 0.929665	valid_1's auc: 0.684851
# [880]	training's auc: 0.93122	valid_1's auc: 0.684869
# [900]	training's auc: 0.932777	valid_1's auc: 0.684776
# [920]	training's auc: 0.934277	valid_1's auc: 0.684742
# Early stopping, best iteration is:
# [737]	training's auc: 0.918086	valid_1's auc: 0.685013
#    INFO ->  AUC: 0.6850133338667197
#    INFO ->  AUC: 0.6850133338667197
#    INFO ->  ReTraining on all data
#    INFO ->  ReTraining on all data
#    INFO ->  train[used_features]:(35831, 108)
#    INFO ->  train[used_features]:(35831, 108)
#    INFO ->  save train[used_features] in ./temp/
#    INFO ->  save train[used_features] in ./temp/
# [20]	training's auc: 0.75599
# [40]	training's auc: 0.762258
# [60]	training's auc: 0.767971
# [80]	training's auc: 0.774998
# [100]	training's auc: 0.780694
# [120]	training's auc: 0.785979
# [140]	training's auc: 0.791191
# [160]	training's auc: 0.796338
# [180]	training's auc: 0.800423
# [200]	training's auc: 0.804887
# [220]	training's auc: 0.80984
# [240]	training's auc: 0.814751
# [260]	training's auc: 0.818934
# [280]	training's auc: 0.82316
# [300]	training's auc: 0.827059
# [320]	training's auc: 0.831316
# [340]	training's auc: 0.835031
# [360]	training's auc: 0.838684
# [380]	training's auc: 0.842644
# [400]	training's auc: 0.846231
# [420]	training's auc: 0.850143
# [440]	training's auc: 0.853803
# [460]	training's auc: 0.85698
# [480]	training's auc: 0.860213
# [500]	training's auc: 0.863561
# [520]	training's auc: 0.866671
# [540]	training's auc: 0.869639
# [560]	training's auc: 0.872605
# [580]	training's auc: 0.87557
# [600]	training's auc: 0.878447
# [620]	training's auc: 0.881089
# [640]	training's auc: 0.883592
# [660]	training's auc: 0.886152
# [680]	training's auc: 0.888618
# [700]	training's auc: 0.890925
# [720]	training's auc: 0.893165
# [740]	training's auc: 0.895377
# [760]	training's auc: 0.897519
# [780]	training's auc: 0.899679
# [800]	training's auc: 0.901707
# [820]	training's auc: 0.903644
# [840]	training's auc: 0.905671
# [860]	training's auc: 0.907521
# [880]	training's auc: 0.909279
# [900]	training's auc: 0.911061
# [920]	training's auc: 0.912751
# [940]	training's auc: 0.914531
#    INFO ->  remain_time: 7132.288138866425 s
#    INFO ->  remain_time: 7132.288138866425 s
#    INFO ->  ##################################################
#    INFO ->  ##################################################
#    INFO ->  base_lgb feature_importances
#    INFO ->  base_lgb feature_importances
#    INFO ->  {'flag1': 2017, 'bill_delta_time__std': 1711, 'browse_delta_time__mean': 1589, 'browse_flag3__std': 1436, 'browse_delta_time__max': 1377, 'browse_flag3__mean': 1338, 'browse_flag2__std': 1331, 'bill_delta_time__median': 1261, 'bill_flag7__max': 1239, 'bill_delta_time__mean': 1136, 'bill_delta_time__max': 1127, 'browse_flag2__mean': 1121, 'bill_flag4__std': 1111, 'bill_flag4__mean': 1082, 'browse_delta_time__std': 1059, 'bill_flag4__median': 1057, 'bill_flag6__max': 936, 'bill_flag3__mean': 923, 'bill_flag6__std': 901, 'bill_flag8__std': 883, 'bill_flag6__median': 877, 'bill_flag7__median': 870, 'bill_flag3__std': 869, 'bill_flag7__std': 851, 'bill_flag4__max': 804, 'bill_flag9__std': 797, 'bill_flag7__mean': 786, 'bill_flag9__mean': 782, 'bill_flag5__mean': 774, 'bill_flag8__mean': 772, 'bill_flag6__min': 752, 'bill_flag13__std': 698, 'bill_flag9__max': 694, 'bill_flag2__std': 686, 'bill_flag13__mean': 682, 'bill_flag6__mean': 681, 'bill_flag2__mean': 670, 'userinfo_flag1': 670, 'bill_flag9__median': 666, 'bill_flag5__std': 662, 'bill_flag3__max': 653, 'bank_flag3__mean': 627, 'bill_flag3__median': 607, 'browse_flag2__min': 548, 'bill_flag13__max': 539, 'bill_delta_time__min': 538, 'browse_flag2__median': 536, 'bill_flag5__max': 520, 'bank_delta_time__max': 514, 'bill_flag7__min': 510, 'bill_flag5__median': 496, 'userinfo_flag3': 486, 'bill_flag11__max': 472, 'browse_flag2__max': 466, 'bill_flag2__median': 455, 'bank_flag3__median': 453, 'bank_flag3__std': 428, 'bank_delta_time__std': 427, 'bank_delta_time__mean': 423, 'bill_flag11__std': 421, 'bank_flag2__mean': 419, 'bill_flag3__min': 364, 'bill_flag11__mean': 360, 'bill_flag13__median': 359, 'bill_flag12__std': 354, 'bank_flag2__std': 321, 'bank_delta_time__median': 315, 'bill_flag8__median': 313, 'bank_flag3__max': 307, 'bill_flag2__min': 303, 'userinfo_flag5': 298, 'bank_flag3__min': 292, 'bill_flag9__min': 271, 'bill_flag12__max': 267, 'bill_flag2__max': 259, 'bill_flag8__max': 248, 'bill_flag5__min': 247, 'browse_flag3__median': 243, 'bill_flag4__min': 241, 'bank_flag4__mean': 238, 'bill_flag12__mean': 228, 'bill_flag10__std': 202, 'bank_flag4__std': 199, 'userinfo_flag4': 168, 'userinfo_flag2': 142, 'bill_flag13__min': 133, 'bill_flag10__mean': 133, 'bill_flag10__min': 115, 'bill_flag11__median': 99, 'bill_flag10__max': 51, 'browse_flag3__max': 48, 'bank_flag4__max': 42, 'bill_flag8__min': 39, 'bill_flag12__min': 29, 'bill_flag11__min': 23, 'bill_flag12__median': 12, 'bill_flag14__mean': 1, 'bill_flag14__median': 0, 'bill_flag10__median': 0, 'bill_flag14__std': 0, 'bank_delta_time__min': 0, 'bank_flag2__max': 0, 'browse_flag3__min': 0, 'browse_delta_time__min': 0, 'bank_flag2__median': 0, 'bank_flag2__min': 0, 'bill_flag14__max': 0, 'browse_delta_time__median': 0}
#    INFO ->  {'flag1': 2017, 'bill_delta_time__std': 1711, 'browse_delta_time__mean': 1589, 'browse_flag3__std': 1436, 'browse_delta_time__max': 1377, 'browse_flag3__mean': 1338, 'browse_flag2__std': 1331, 'bill_delta_time__median': 1261, 'bill_flag7__max': 1239, 'bill_delta_time__mean': 1136, 'bill_delta_time__max': 1127, 'browse_flag2__mean': 1121, 'bill_flag4__std': 1111, 'bill_flag4__mean': 1082, 'browse_delta_time__std': 1059, 'bill_flag4__median': 1057, 'bill_flag6__max': 936, 'bill_flag3__mean': 923, 'bill_flag6__std': 901, 'bill_flag8__std': 883, 'bill_flag6__median': 877, 'bill_flag7__median': 870, 'bill_flag3__std': 869, 'bill_flag7__std': 851, 'bill_flag4__max': 804, 'bill_flag9__std': 797, 'bill_flag7__mean': 786, 'bill_flag9__mean': 782, 'bill_flag5__mean': 774, 'bill_flag8__mean': 772, 'bill_flag6__min': 752, 'bill_flag13__std': 698, 'bill_flag9__max': 694, 'bill_flag2__std': 686, 'bill_flag13__mean': 682, 'bill_flag6__mean': 681, 'bill_flag2__mean': 670, 'userinfo_flag1': 670, 'bill_flag9__median': 666, 'bill_flag5__std': 662, 'bill_flag3__max': 653, 'bank_flag3__mean': 627, 'bill_flag3__median': 607, 'browse_flag2__min': 548, 'bill_flag13__max': 539, 'bill_delta_time__min': 538, 'browse_flag2__median': 536, 'bill_flag5__max': 520, 'bank_delta_time__max': 514, 'bill_flag7__min': 510, 'bill_flag5__median': 496, 'userinfo_flag3': 486, 'bill_flag11__max': 472, 'browse_flag2__max': 466, 'bill_flag2__median': 455, 'bank_flag3__median': 453, 'bank_flag3__std': 428, 'bank_delta_time__std': 427, 'bank_delta_time__mean': 423, 'bill_flag11__std': 421, 'bank_flag2__mean': 419, 'bill_flag3__min': 364, 'bill_flag11__mean': 360, 'bill_flag13__median': 359, 'bill_flag12__std': 354, 'bank_flag2__std': 321, 'bank_delta_time__median': 315, 'bill_flag8__median': 313, 'bank_flag3__max': 307, 'bill_flag2__min': 303, 'userinfo_flag5': 298, 'bank_flag3__min': 292, 'bill_flag9__min': 271, 'bill_flag12__max': 267, 'bill_flag2__max': 259, 'bill_flag8__max': 248, 'bill_flag5__min': 247, 'browse_flag3__median': 243, 'bill_flag4__min': 241, 'bank_flag4__mean': 238, 'bill_flag12__mean': 228, 'bill_flag10__std': 202, 'bank_flag4__std': 199, 'userinfo_flag4': 168, 'userinfo_flag2': 142, 'bill_flag13__min': 133, 'bill_flag10__mean': 133, 'bill_flag10__min': 115, 'bill_flag11__median': 99, 'bill_flag10__max': 51, 'browse_flag3__max': 48, 'bank_flag4__max': 42, 'bill_flag8__min': 39, 'bill_flag12__min': 29, 'bill_flag11__min': 23, 'bill_flag12__median': 12, 'bill_flag14__mean': 1, 'bill_flag14__median': 0, 'bill_flag10__median': 0, 'bill_flag14__std': 0, 'bank_delta_time__min': 0, 'bank_flag2__max': 0, 'browse_flag3__min': 0, 'browse_delta_time__min': 0, 'bank_flag2__median': 0, 'bank_flag2__min': 0, 'bill_flag14__max': 0, 'browse_delta_time__median': 0}
#    INFO ->  [+] feature engineer, generate_concat
#    INFO ->  [+] feature engineer, generate_concat
#    INFO ->  used_concat_cols: []
#    INFO ->  used_concat_cols: []
#    INFO ->  concat_features: []
#    INFO ->  concat_features: []
#    INFO ->  remain_time: 7132.28330206871 s
#    INFO ->  remain_time: 7132.28330206871 s
#    INFO ->  [+] feature engineer, onehot
#    INFO ->  [+] feature engineer, onehot
#    INFO ->  onehot features: []
#    INFO ->  onehot features: []
#    INFO ->  remain_time: 7132.278893232346 s
#    INFO ->  remain_time: 7132.278893232346 s
#    INFO ->  [+] feature engineer, count
#    INFO ->  [+] feature engineer, count
# 100%|██████████| 1/1 [00:00<00:00, 76.79it/s]
#    INFO ->  count features: []
#    INFO ->  count features: []
# 0it [00:00, ?it/s]
#    INFO ->  remain_time: 7132.257400512695 s
#    INFO ->  remain_time: 7132.257400512695 s
#    INFO ->  [+] feature engineer, shift
#    INFO ->  [+] feature engineer, shift
#    INFO ->  shift features: []
#    INFO ->  shift features: []
#    INFO ->  remain_time: 7132.21436715126 s
#    INFO ->  remain_time: 7132.21436715126 s
#    INFO ->  [+] feature engineer, time_diff
#    INFO ->  [+] feature engineer, time_diff
#    INFO ->  big_cols_Unix_timestamp: ['flag1']
#    INFO ->  big_cols_Unix_timestamp: ['flag1']
#    INFO ->  big_cols_datetime: []
#    INFO ->  big_cols_datetime: []
# 100%|██████████| 1/1 [00:00<00:00,  3.57it/s]
#    INFO ->  remain_time: 7131.928342342377 s
#    INFO ->  remain_time: 7131.928342342377 s
#    INFO ->  [+] merge_table
#    INFO ->  [+] merge_table
#    INFO ->  shape of BIG: (35831, 111)
#    INFO ->  shape of BIG: (35831, 111)
#    INFO ->  delete column: {}
#    INFO ->  delete column: {}
#    INFO ->  shape of FE_onehot: (35831, 0)
#    INFO ->  shape of FE_onehot: (35831, 0)
#    INFO ->  delete column: {}
#    INFO ->  delete column: {}
#    INFO ->  shape of FE_count: (35831, 0)
#    INFO ->  shape of FE_count: (35831, 0)
#    INFO ->  delete column: {}
#    INFO ->  delete column: {}
#    INFO ->  shape of FE_shift: (0, 0)
#    INFO ->  shape of FE_shift: (0, 0)
#    INFO ->  delete column: ['new_user_id_flag1_diff_1', 'new_user_id_flag1_diff_2', 'new_user_id_flag1_diff_3']
#    INFO ->  delete column: ['new_user_id_flag1_diff_1', 'new_user_id_flag1_diff_2', 'new_user_id_flag1_diff_3']
#    INFO ->  shape of FE_cat_time_diff: (35831, 0)
#    INFO ->  shape of FE_cat_time_diff: (35831, 0)
#    INFO ->  shape after fe: (35831, 111)
#    INFO ->  shape after fe: (35831, 111)
#    INFO ->  remain_time: 7131.84779047966 s
#    INFO ->  remain_time: 7131.84779047966 s
#    INFO ->  [+] fe_lgb lightgbm
#    INFO ->  [+] fe_lgb lightgbm
#    INFO ->  train.shape: (35831, 111)
#    INFO ->  train.shape: (35831, 111)
#    INFO ->  train[used_features].shape: (35831, 108)
#    INFO ->  train[used_features].shape: (35831, 108)
#    INFO ->  split data with time
#    INFO ->  split data with time
#    INFO ->  use time series index
#    INFO ->  use time series index
#    INFO ->  28905 for train, 6926 for valid
#    INFO ->  28905 for train, 6926 for valid
#    INFO ->  [+] Pre training for estimate time
#    INFO ->  [+] Pre training for estimate time
#    INFO ->  estimate time: 96.28880023956299
#    INFO ->  estimate time: 96.28880023956299
#    INFO ->  [+] Formal training
#    INFO ->  [+] Formal training
# Training until validation scores don't improve for 200 rounds
# Did not meet early stopping. Best iteration is:
# [10]	training's auc: 0.759157	valid_1's auc: 0.656721
# Training until validation scores don't improve for 200 rounds
# [20]	training's auc: 0.767075	valid_1's auc: 0.660453
# [40]	training's auc: 0.775653	valid_1's auc: 0.662762
# [60]	training's auc: 0.781959	valid_1's auc: 0.666735
# [80]	training's auc: 0.789956	valid_1's auc: 0.668075
# [100]	training's auc: 0.796783	valid_1's auc: 0.66879
# [120]	training's auc: 0.802392	valid_1's auc: 0.671436
# [140]	training's auc: 0.808669	valid_1's auc: 0.672589
# [160]	training's auc: 0.814185	valid_1's auc: 0.673169
# [180]	training's auc: 0.819183	valid_1's auc: 0.674239
# [200]	training's auc: 0.824508	valid_1's auc: 0.674351
# [220]	training's auc: 0.829584	valid_1's auc: 0.675045
# [240]	training's auc: 0.835224	valid_1's auc: 0.676011
# [260]	training's auc: 0.839982	valid_1's auc: 0.676391
# [280]	training's auc: 0.845004	valid_1's auc: 0.677245
# [300]	training's auc: 0.849455	valid_1's auc: 0.678096
# [320]	training's auc: 0.854001	valid_1's auc: 0.678283
# [340]	training's auc: 0.858391	valid_1's auc: 0.67877
# [360]	training's auc: 0.86241	valid_1's auc: 0.679254
# [380]	training's auc: 0.866517	valid_1's auc: 0.679821
# [400]	training's auc: 0.870232	valid_1's auc: 0.679983
# [420]	training's auc: 0.873968	valid_1's auc: 0.680355
# [440]	training's auc: 0.877464	valid_1's auc: 0.680735
# [460]	training's auc: 0.881054	valid_1's auc: 0.681485
# [480]	training's auc: 0.884395	valid_1's auc: 0.682113
# [500]	training's auc: 0.887649	valid_1's auc: 0.682616
# [520]	training's auc: 0.890713	valid_1's auc: 0.682856
# [540]	training's auc: 0.893552	valid_1's auc: 0.683307
# [560]	training's auc: 0.896741	valid_1's auc: 0.683624
# [580]	training's auc: 0.899609	valid_1's auc: 0.683823
# [600]	training's auc: 0.902351	valid_1's auc: 0.684042
# [620]	training's auc: 0.904909	valid_1's auc: 0.683965
# [640]	training's auc: 0.907515	valid_1's auc: 0.684016
# [660]	training's auc: 0.909928	valid_1's auc: 0.68438
# [680]	training's auc: 0.912079	valid_1's auc: 0.68453
# [700]	training's auc: 0.914231	valid_1's auc: 0.684565
# [720]	training's auc: 0.916318	valid_1's auc: 0.684794
# [740]	training's auc: 0.918415	valid_1's auc: 0.684861
# [760]	training's auc: 0.92048	valid_1's auc: 0.684672
# [780]	training's auc: 0.922477	valid_1's auc: 0.684803
# [800]	training's auc: 0.924301	valid_1's auc: 0.684891
# [820]	training's auc: 0.926077	valid_1's auc: 0.684967
# [840]	training's auc: 0.927905	valid_1's auc: 0.684963
# [860]	training's auc: 0.929665	valid_1's auc: 0.684851
# [880]	training's auc: 0.93122	valid_1's auc: 0.684869
# [900]	training's auc: 0.932777	valid_1's auc: 0.684776
# [920]	training's auc: 0.934277	valid_1's auc: 0.684742
# Early stopping, best iteration is:
# [737]	training's auc: 0.918086	valid_1's auc: 0.685013
#    INFO ->  AUC: 0.6850133338667197
#    INFO ->  AUC: 0.6850133338667197
#    INFO ->  ReTraining on all data
#    INFO ->  ReTraining on all data
#    INFO ->  train[used_features]:(35831, 108)
#    INFO ->  train[used_features]:(35831, 108)
#    INFO ->  save train[used_features] in ./temp/
#    INFO ->  save train[used_features] in ./temp/
# [20]	training's auc: 0.75599
# [40]	training's auc: 0.762258
# [60]	training's auc: 0.767971
# [80]	training's auc: 0.774998
# [100]	training's auc: 0.780694
# [120]	training's auc: 0.785979
# [140]	training's auc: 0.791191
# [160]	training's auc: 0.796338
# [180]	training's auc: 0.800423
# [200]	training's auc: 0.804887
# [220]	training's auc: 0.80984
# [240]	training's auc: 0.814751
# [260]	training's auc: 0.818934
# [280]	training's auc: 0.82316
# [300]	training's auc: 0.827059
# [320]	training's auc: 0.831316
# [340]	training's auc: 0.835031
# [360]	training's auc: 0.838684
# [380]	training's auc: 0.842644
# [400]	training's auc: 0.846231
# [420]	training's auc: 0.850143
# [440]	training's auc: 0.853803
# [460]	training's auc: 0.85698
# [480]	training's auc: 0.860213
# [500]	training's auc: 0.863561
# [520]	training's auc: 0.866671
# [540]	training's auc: 0.869639
# [560]	training's auc: 0.872605
# [580]	training's auc: 0.87557
# [600]	training's auc: 0.878447
# [620]	training's auc: 0.881089
# [640]	training's auc: 0.883592
# [660]	training's auc: 0.886152
# [680]	training's auc: 0.888618
# [700]	training's auc: 0.890925
# [720]	training's auc: 0.893165
# [740]	training's auc: 0.895377
# [760]	training's auc: 0.897519
# [780]	training's auc: 0.899679
# [800]	training's auc: 0.901707
# [820]	training's auc: 0.903644
# [840]	training's auc: 0.905671
# [860]	training's auc: 0.907521
# [880]	training's auc: 0.909279
# [900]	training's auc: 0.911061
# [920]	training's auc: 0.912751
# [940]	training's auc: 0.914531
#    INFO ->  remain_time: 7108.277445077896 s
#    INFO ->  remain_time: 7108.277445077896 s
#    INFO ->  ##################################################
#    INFO ->  ##################################################
#    INFO ->  fe_lgb feature_importances
#    INFO ->  fe_lgb feature_importances
#    INFO ->  {'flag1': 2017, 'bill_delta_time__std': 1711, 'browse_delta_time__mean': 1589, 'browse_flag3__std': 1436, 'browse_delta_time__max': 1377, 'browse_flag3__mean': 1338, 'browse_flag2__std': 1331, 'bill_delta_time__median': 1261, 'bill_flag7__max': 1239, 'bill_delta_time__mean': 1136, 'bill_delta_time__max': 1127, 'browse_flag2__mean': 1121, 'bill_flag4__std': 1111, 'bill_flag4__mean': 1082, 'browse_delta_time__std': 1059, 'bill_flag4__median': 1057, 'bill_flag6__max': 936, 'bill_flag3__mean': 923, 'bill_flag6__std': 901, 'bill_flag8__std': 883, 'bill_flag6__median': 877, 'bill_flag7__median': 870, 'bill_flag3__std': 869, 'bill_flag7__std': 851, 'bill_flag4__max': 804, 'bill_flag9__std': 797, 'bill_flag7__mean': 786, 'bill_flag9__mean': 782, 'bill_flag5__mean': 774, 'bill_flag8__mean': 772, 'bill_flag6__min': 752, 'bill_flag13__std': 698, 'bill_flag9__max': 694, 'bill_flag2__std': 686, 'bill_flag13__mean': 682, 'bill_flag6__mean': 681, 'bill_flag2__mean': 670, 'userinfo_flag1': 670, 'bill_flag9__median': 666, 'bill_flag5__std': 662, 'bill_flag3__max': 653, 'bank_flag3__mean': 627, 'bill_flag3__median': 607, 'browse_flag2__min': 548, 'bill_flag13__max': 539, 'bill_delta_time__min': 538, 'browse_flag2__median': 536, 'bill_flag5__max': 520, 'bank_delta_time__max': 514, 'bill_flag7__min': 510, 'bill_flag5__median': 496, 'userinfo_flag3': 486, 'bill_flag11__max': 472, 'browse_flag2__max': 466, 'bill_flag2__median': 455, 'bank_flag3__median': 453, 'bank_flag3__std': 428, 'bank_delta_time__std': 427, 'bank_delta_time__mean': 423, 'bill_flag11__std': 421, 'bank_flag2__mean': 419, 'bill_flag3__min': 364, 'bill_flag11__mean': 360, 'bill_flag13__median': 359, 'bill_flag12__std': 354, 'bank_flag2__std': 321, 'bank_delta_time__median': 315, 'bill_flag8__median': 313, 'bank_flag3__max': 307, 'bill_flag2__min': 303, 'userinfo_flag5': 298, 'bank_flag3__min': 292, 'bill_flag9__min': 271, 'bill_flag12__max': 267, 'bill_flag2__max': 259, 'bill_flag8__max': 248, 'bill_flag5__min': 247, 'browse_flag3__median': 243, 'bill_flag4__min': 241, 'bank_flag4__mean': 238, 'bill_flag12__mean': 228, 'bill_flag10__std': 202, 'bank_flag4__std': 199, 'userinfo_flag4': 168, 'userinfo_flag2': 142, 'bill_flag13__min': 133, 'bill_flag10__mean': 133, 'bill_flag10__min': 115, 'bill_flag11__median': 99, 'bill_flag10__max': 51, 'browse_flag3__max': 48, 'bank_flag4__max': 42, 'bill_flag8__min': 39, 'bill_flag12__min': 29, 'bill_flag11__min': 23, 'bill_flag12__median': 12, 'bill_flag14__mean': 1, 'bill_flag14__median': 0, 'bill_flag10__median': 0, 'bill_flag14__std': 0, 'bank_delta_time__min': 0, 'bank_flag2__max': 0, 'browse_flag3__min': 0, 'browse_delta_time__min': 0, 'bank_flag2__median': 0, 'bank_flag2__min': 0, 'bill_flag14__max': 0, 'browse_delta_time__median': 0}
#    INFO ->  {'flag1': 2017, 'bill_delta_time__std': 1711, 'browse_delta_time__mean': 1589, 'browse_flag3__std': 1436, 'browse_delta_time__max': 1377, 'browse_flag3__mean': 1338, 'browse_flag2__std': 1331, 'bill_delta_time__median': 1261, 'bill_flag7__max': 1239, 'bill_delta_time__mean': 1136, 'bill_delta_time__max': 1127, 'browse_flag2__mean': 1121, 'bill_flag4__std': 1111, 'bill_flag4__mean': 1082, 'browse_delta_time__std': 1059, 'bill_flag4__median': 1057, 'bill_flag6__max': 936, 'bill_flag3__mean': 923, 'bill_flag6__std': 901, 'bill_flag8__std': 883, 'bill_flag6__median': 877, 'bill_flag7__median': 870, 'bill_flag3__std': 869, 'bill_flag7__std': 851, 'bill_flag4__max': 804, 'bill_flag9__std': 797, 'bill_flag7__mean': 786, 'bill_flag9__mean': 782, 'bill_flag5__mean': 774, 'bill_flag8__mean': 772, 'bill_flag6__min': 752, 'bill_flag13__std': 698, 'bill_flag9__max': 694, 'bill_flag2__std': 686, 'bill_flag13__mean': 682, 'bill_flag6__mean': 681, 'bill_flag2__mean': 670, 'userinfo_flag1': 670, 'bill_flag9__median': 666, 'bill_flag5__std': 662, 'bill_flag3__max': 653, 'bank_flag3__mean': 627, 'bill_flag3__median': 607, 'browse_flag2__min': 548, 'bill_flag13__max': 539, 'bill_delta_time__min': 538, 'browse_flag2__median': 536, 'bill_flag5__max': 520, 'bank_delta_time__max': 514, 'bill_flag7__min': 510, 'bill_flag5__median': 496, 'userinfo_flag3': 486, 'bill_flag11__max': 472, 'browse_flag2__max': 466, 'bill_flag2__median': 455, 'bank_flag3__median': 453, 'bank_flag3__std': 428, 'bank_delta_time__std': 427, 'bank_delta_time__mean': 423, 'bill_flag11__std': 421, 'bank_flag2__mean': 419, 'bill_flag3__min': 364, 'bill_flag11__mean': 360, 'bill_flag13__median': 359, 'bill_flag12__std': 354, 'bank_flag2__std': 321, 'bank_delta_time__median': 315, 'bill_flag8__median': 313, 'bank_flag3__max': 307, 'bill_flag2__min': 303, 'userinfo_flag5': 298, 'bank_flag3__min': 292, 'bill_flag9__min': 271, 'bill_flag12__max': 267, 'bill_flag2__max': 259, 'bill_flag8__max': 248, 'bill_flag5__min': 247, 'browse_flag3__median': 243, 'bill_flag4__min': 241, 'bank_flag4__mean': 238, 'bill_flag12__mean': 228, 'bill_flag10__std': 202, 'bank_flag4__std': 199, 'userinfo_flag4': 168, 'userinfo_flag2': 142, 'bill_flag13__min': 133, 'bill_flag10__mean': 133, 'bill_flag10__min': 115, 'bill_flag11__median': 99, 'bill_flag10__max': 51, 'browse_flag3__max': 48, 'bank_flag4__max': 42, 'bill_flag8__min': 39, 'bill_flag12__min': 29, 'bill_flag11__min': 23, 'bill_flag12__median': 12, 'bill_flag14__mean': 1, 'bill_flag14__median': 0, 'bill_flag10__median': 0, 'bill_flag14__std': 0, 'bank_delta_time__min': 0, 'bank_flag2__max': 0, 'browse_flag3__min': 0, 'browse_delta_time__min': 0, 'bank_flag2__median': 0, 'bank_flag2__min': 0, 'bill_flag14__max': 0, 'browse_delta_time__median': 0}
#    INFO ->  [+] fe_lgb_opt lightgbm
#    INFO ->  [+] fe_lgb_opt lightgbm
#    INFO ->  train.shape: (35831, 111)
#    INFO ->  train.shape: (35831, 111)
#    INFO ->  train[used_features].shape: (35831, 108)
#    INFO ->  train[used_features].shape: (35831, 108)
#    INFO ->  split data with time
#    INFO ->  split data with time
#    INFO ->  use time series index
#    INFO ->  use time series index
#    INFO ->  28905 for train, 6926 for valid
#    INFO ->  28905 for train, 6926 for valid
#    INFO ->  [+] Pre training for estimate time
#    INFO ->  [+] Pre training for estimate time
#    INFO ->  estimate time: 113.25579881668091
#    INFO ->  estimate time: 113.25579881668091
#    INFO ->  [+] Formal training
#    INFO ->  [+] Formal training
# Training until validation scores don't improve for 200 rounds
# Did not meet early stopping. Best iteration is:
# [10]	training's auc: 0.861311	valid_1's auc: 0.652497
# Training until validation scores don't improve for 200 rounds
# [20]	training's auc: 0.87567	valid_1's auc: 0.658866
# [40]	training's auc: 0.887248	valid_1's auc: 0.664126
# [60]	training's auc: 0.894299	valid_1's auc: 0.667522
# [80]	training's auc: 0.903176	valid_1's auc: 0.669581
# [100]	training's auc: 0.910207	valid_1's auc: 0.670391
# [120]	training's auc: 0.915491	valid_1's auc: 0.673183
# [140]	training's auc: 0.920743	valid_1's auc: 0.675192
# [160]	training's auc: 0.92573	valid_1's auc: 0.675539
# [180]	training's auc: 0.930027	valid_1's auc: 0.675798
# [200]	training's auc: 0.934921	valid_1's auc: 0.675973
# [220]	training's auc: 0.939376	valid_1's auc: 0.675398
# [240]	training's auc: 0.943732	valid_1's auc: 0.67465
# [260]	training's auc: 0.947139	valid_1's auc: 0.675144
# [280]	training's auc: 0.950706	valid_1's auc: 0.675505
# [300]	training's auc: 0.953811	valid_1's auc: 0.675076
# [320]	training's auc: 0.956933	valid_1's auc: 0.674914
# [340]	training's auc: 0.959586	valid_1's auc: 0.675377
# [360]	training's auc: 0.962308	valid_1's auc: 0.675614
# [380]	training's auc: 0.964869	valid_1's auc: 0.676427
# [400]	training's auc: 0.967201	valid_1's auc: 0.676779
# [420]	training's auc: 0.969403	valid_1's auc: 0.676832
# [440]	training's auc: 0.971324	valid_1's auc: 0.677497
# [460]	training's auc: 0.973085	valid_1's auc: 0.677995
# [480]	training's auc: 0.974797	valid_1's auc: 0.678136
# [500]	training's auc: 0.976409	valid_1's auc: 0.678701
# [520]	training's auc: 0.977919	valid_1's auc: 0.678548
# [540]	training's auc: 0.97911	valid_1's auc: 0.678738
# [560]	training's auc: 0.98031	valid_1's auc: 0.678309
# [580]	training's auc: 0.981432	valid_1's auc: 0.678356
# [600]	training's auc: 0.982499	valid_1's auc: 0.678328
# [620]	training's auc: 0.983476	valid_1's auc: 0.677866
# [640]	training's auc: 0.98436	valid_1's auc: 0.677761
# [660]	training's auc: 0.98515	valid_1's auc: 0.677802
# [680]	training's auc: 0.98593	valid_1's auc: 0.677419
# [700]	training's auc: 0.986611	valid_1's auc: 0.677359
# [720]	training's auc: 0.987326	valid_1's auc: 0.677269
# [740]	training's auc: 0.987906	valid_1's auc: 0.677245
# Early stopping, best iteration is:
# [547]	training's auc: 0.979558	valid_1's auc: 0.678874
#    INFO ->  AUC: 0.6788741514433263
#    INFO ->  AUC: 0.6788741514433263
#    INFO ->  ReTraining on all data
#    INFO ->  ReTraining on all data
#    INFO ->  train[used_features]:(35831, 108)
#    INFO ->  train[used_features]:(35831, 108)
#    INFO ->  save train[used_features] in ./temp/
#    INFO ->  save train[used_features] in ./temp/
# [20]	training's auc: 0.851565
# [40]	training's auc: 0.864403
# [60]	training's auc: 0.872209
# [80]	training's auc: 0.881467
# [100]	training's auc: 0.88853
# [120]	training's auc: 0.894455
# [140]	training's auc: 0.900491
# [160]	training's auc: 0.905691
# [180]	training's auc: 0.91034
# [200]	training's auc: 0.915345
# [220]	training's auc: 0.920295
# [240]	training's auc: 0.925024
# [260]	training's auc: 0.929066
# [280]	training's auc: 0.933221
# [300]	training's auc: 0.936982
# [320]	training's auc: 0.940556
# [340]	training's auc: 0.943677
# [360]	training's auc: 0.946844
# [380]	training's auc: 0.949861
# [400]	training's auc: 0.952602
# [420]	training's auc: 0.955279
# [440]	training's auc: 0.957731
# [460]	training's auc: 0.959898
# [480]	training's auc: 0.96198
# [500]	training's auc: 0.964246
# [520]	training's auc: 0.966221
# [540]	training's auc: 0.967908
# [560]	training's auc: 0.969526
# [580]	training's auc: 0.971056
# [600]	training's auc: 0.972547
# [620]	training's auc: 0.973845
# [640]	training's auc: 0.975133
# [660]	training's auc: 0.976314
# [680]	training's auc: 0.977458
# [700]	training's auc: 0.978547
#    INFO ->  remain_time: 7073.014182329178 s
#    INFO ->  remain_time: 7073.014182329178 s
#    INFO ->  ##################################################
#    INFO ->  ##################################################
#    INFO ->  fe_lgb_opt feature_importances
#    INFO ->  fe_lgb_opt feature_importances
#    INFO ->  {'flag1': 4188, 'browse_flag2__std': 3990, 'browse_flag3__std': 3762, 'browse_flag3__mean': 3709, 'browse_delta_time__mean': 3486, 'browse_flag2__mean': 3342, 'bill_delta_time__std': 3291, 'browse_delta_time__max': 3213, 'bill_flag7__max': 3108, 'browse_delta_time__std': 2668, 'bill_flag9__std': 2650, 'bill_flag6__median': 2646, 'bill_delta_time__max': 2635, 'bill_flag4__std': 2603, 'bill_flag4__mean': 2591, 'bill_delta_time__median': 2551, 'bill_delta_time__mean': 2538, 'bill_flag6__max': 2455, 'bill_flag7__median': 2445, 'bill_flag4__median': 2422, 'bill_flag6__std': 2421, 'bill_flag3__std': 2391, 'bill_flag7__mean': 2369, 'bill_flag6__mean': 2283, 'bill_flag7__std': 2278, 'bill_flag5__mean': 2216, 'bill_flag8__std': 2200, 'bill_flag4__max': 2160, 'bill_flag3__mean': 2101, 'bill_flag6__min': 2060, 'bill_flag9__mean': 2041, 'bill_flag2__mean': 2010, 'bill_flag9__max': 2007, 'bill_flag8__mean': 1985, 'bill_flag5__std': 1973, 'bill_flag2__std': 1881, 'bill_flag9__median': 1868, 'bill_flag13__std': 1865, 'bill_flag3__max': 1857, 'bill_flag13__mean': 1809, 'browse_flag2__min': 1706, 'bill_flag3__median': 1658, 'browse_flag2__median': 1650, 'bill_flag7__min': 1598, 'bill_flag13__max': 1339, 'bill_flag5__median': 1318, 'bill_flag5__max': 1315, 'bill_delta_time__min': 1236, 'browse_flag2__max': 1161, 'bank_flag3__mean': 1111, 'bill_flag2__median': 1081, 'bill_flag11__std': 1001, 'bill_flag11__max': 997, 'bank_flag3__std': 970, 'bill_flag11__mean': 908, 'bank_delta_time__max': 903, 'bill_flag13__median': 899, 'bank_delta_time__mean': 882, 'bill_flag3__min': 873, 'userinfo_flag5': 873, 'bill_flag2__min': 846, 'bank_flag2__mean': 845, 'userinfo_flag3': 822, 'bank_delta_time__std': 798, 'bill_flag9__min': 789, 'bank_flag3__max': 788, 'bank_flag2__std': 773, 'bill_flag8__max': 707, 'bank_flag3__median': 704, 'browse_flag3__median': 683, 'bill_flag2__max': 682, 'userinfo_flag1': 638, 'bill_flag8__median': 638, 'bill_flag5__min': 622, 'userinfo_flag4': 598, 'bill_flag4__min': 595, 'bill_flag12__std': 555, 'bank_delta_time__median': 463, 'bill_flag12__mean': 453, 'bill_flag12__max': 435, 'userinfo_flag2': 416, 'bank_flag4__mean': 404, 'bill_flag10__std': 367, 'bill_flag13__min': 358, 'bank_flag3__min': 343, 'bank_flag4__std': 275, 'bill_flag10__mean': 234, 'bill_flag11__median': 194, 'bill_flag10__min': 177, 'bill_flag10__max': 113, 'browse_flag3__max': 105, 'bill_flag8__min': 83, 'bank_flag4__max': 63, 'bill_flag12__min': 36, 'bill_flag11__min': 35, 'bill_flag12__median': 14, 'bill_flag14__mean': 2, 'bank_flag2__median': 0, 'bank_flag2__max': 0, 'bank_flag2__min': 0, 'browse_delta_time__median': 0, 'browse_flag3__min': 0, 'bank_delta_time__min': 0, 'browse_delta_time__min': 0, 'bill_flag14__std': 0, 'bill_flag14__max': 0, 'bill_flag14__median': 0, 'bill_flag10__median': 0}
#    INFO ->  {'flag1': 4188, 'browse_flag2__std': 3990, 'browse_flag3__std': 3762, 'browse_flag3__mean': 3709, 'browse_delta_time__mean': 3486, 'browse_flag2__mean': 3342, 'bill_delta_time__std': 3291, 'browse_delta_time__max': 3213, 'bill_flag7__max': 3108, 'browse_delta_time__std': 2668, 'bill_flag9__std': 2650, 'bill_flag6__median': 2646, 'bill_delta_time__max': 2635, 'bill_flag4__std': 2603, 'bill_flag4__mean': 2591, 'bill_delta_time__median': 2551, 'bill_delta_time__mean': 2538, 'bill_flag6__max': 2455, 'bill_flag7__median': 2445, 'bill_flag4__median': 2422, 'bill_flag6__std': 2421, 'bill_flag3__std': 2391, 'bill_flag7__mean': 2369, 'bill_flag6__mean': 2283, 'bill_flag7__std': 2278, 'bill_flag5__mean': 2216, 'bill_flag8__std': 2200, 'bill_flag4__max': 2160, 'bill_flag3__mean': 2101, 'bill_flag6__min': 2060, 'bill_flag9__mean': 2041, 'bill_flag2__mean': 2010, 'bill_flag9__max': 2007, 'bill_flag8__mean': 1985, 'bill_flag5__std': 1973, 'bill_flag2__std': 1881, 'bill_flag9__median': 1868, 'bill_flag13__std': 1865, 'bill_flag3__max': 1857, 'bill_flag13__mean': 1809, 'browse_flag2__min': 1706, 'bill_flag3__median': 1658, 'browse_flag2__median': 1650, 'bill_flag7__min': 1598, 'bill_flag13__max': 1339, 'bill_flag5__median': 1318, 'bill_flag5__max': 1315, 'bill_delta_time__min': 1236, 'browse_flag2__max': 1161, 'bank_flag3__mean': 1111, 'bill_flag2__median': 1081, 'bill_flag11__std': 1001, 'bill_flag11__max': 997, 'bank_flag3__std': 970, 'bill_flag11__mean': 908, 'bank_delta_time__max': 903, 'bill_flag13__median': 899, 'bank_delta_time__mean': 882, 'bill_flag3__min': 873, 'userinfo_flag5': 873, 'bill_flag2__min': 846, 'bank_flag2__mean': 845, 'userinfo_flag3': 822, 'bank_delta_time__std': 798, 'bill_flag9__min': 789, 'bank_flag3__max': 788, 'bank_flag2__std': 773, 'bill_flag8__max': 707, 'bank_flag3__median': 704, 'browse_flag3__median': 683, 'bill_flag2__max': 682, 'userinfo_flag1': 638, 'bill_flag8__median': 638, 'bill_flag5__min': 622, 'userinfo_flag4': 598, 'bill_flag4__min': 595, 'bill_flag12__std': 555, 'bank_delta_time__median': 463, 'bill_flag12__mean': 453, 'bill_flag12__max': 435, 'userinfo_flag2': 416, 'bank_flag4__mean': 404, 'bill_flag10__std': 367, 'bill_flag13__min': 358, 'bank_flag3__min': 343, 'bank_flag4__std': 275, 'bill_flag10__mean': 234, 'bill_flag11__median': 194, 'bill_flag10__min': 177, 'bill_flag10__max': 113, 'browse_flag3__max': 105, 'bill_flag8__min': 83, 'bank_flag4__max': 63, 'bill_flag12__min': 36, 'bill_flag11__min': 35, 'bill_flag12__median': 14, 'bill_flag14__mean': 2, 'bank_flag2__median': 0, 'bank_flag2__max': 0, 'bank_flag2__min': 0, 'browse_delta_time__median': 0, 'browse_flag3__min': 0, 'bank_delta_time__min': 0, 'browse_delta_time__min': 0, 'bill_flag14__std': 0, 'bill_flag14__max': 0, 'bill_flag14__median': 0, 'bill_flag10__median': 0}
#    INFO ->  remain_time: 7037.735439300537 s
#    INFO ->  remain_time: 7037.735439300537 s
#    INFO ->  remain_time: 7037.73542881012 s
#    INFO ->  remain_time: 7037.73542881012 s

# %%
save_path = './save'

import os
os.makedirs(save_path, exist_ok = True)

# %%
autoxserver.save_server(save_path)
