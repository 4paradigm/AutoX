# %%
import sys
sys.path.append('../')

# %%
from autox import AutoXServer
# Out:
# /home/caihengxing/anaconda3/lib/python3.7/site-packages/pandas/compat/_optional.py:138: UserWarning: Pandas requires version '2.7.0' or newer of 'numexpr' (version '2.6.9' currently installed).
#   warnings.warn(msg, UserWarning)

# %%
data_info_path = '/home/caihengxing/taac_data/bank/data_info.json'
train_set_path = '/home/caihengxing/taac_data/bank/train_data'

# %%
autoxserver = AutoXServer(is_train = True, server_name = 'bank_1231',
                          data_info_path = data_info_path, train_set_path = train_set_path)
autoxserver.fit()
# Out:
#    INFO ->  data name: bank_1231
#    INFO ->  data name: bank_1231
#    INFO ->  *** phase: train
#    INFO ->  *** phase: train
#    INFO ->  read data_info.json
#    INFO ->  read data_info.json
# ...

# %%
save_path = '/home/caihengxing/automl_for_competition/save'
autoxserver.save_server(save_path)
