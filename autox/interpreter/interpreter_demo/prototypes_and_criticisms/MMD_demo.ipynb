# %% [markdown]
# ## import library

# %%
import sys
sys.path.append('../../')

# %%
import pandas as pd
import numpy as np
import os
import math
import matplotlib.pyplot as plt
from pathlib import Path
from sklearn.datasets import load_svmlight_file
import torch
from mlinterpreter.mmd.mmd_critic import Dataset, select_prototypes, select_criticisms
from tqdm import tqdm, tqdm_notebook
from sklearn.preprocessing import StandardScaler
from sklearn import preprocessing

# %%
def load_data(path, target):
    df = pd.read_csv(path)
    df_origin = df.copy()
    
    num_cols = []
    cat_cols = []

    for col in df.columns:
        if col in [target]:
            continue
        if (df[col].dtype == 'object'):
            cat_cols.append(col)
        else:
            num_cols.append(col)
    
    for col in num_cols:
        scaler = StandardScaler()
        scaler.fit(df[col].values.reshape(-1, 1))

        df[col] = scaler.transform(df[col].values.reshape(-1, 1))
    
    
    for f in cat_cols:
        lbl = preprocessing.LabelEncoder()
        print(f, df[f].nunique())
        lbl.fit(df[f])
        df[f] = lbl.transform(list(df[f].astype(str)))
    
    not_used = [target]
    used_features = [x for x in df.columns if x not in not_used]
    X = df[used_features]
    y = df[target]
    
    X = torch.tensor(np.array(X), dtype=torch.float)
    y = torch.tensor(np.array(y), dtype=torch.long)
    
    return X, y, df_origin

# %% [markdown]
# ## parameter setting

# %%
gamma = 0.026

num_prototypes = 32
num_criticisms = 10

kernel_type = 'local'
# kernel_type = 'global'

# regularizer = None
regularizer = 'logdet'
# regularizer = 'iterative'

path = '../../demo_data/adult.csv'
target = 'income'

# %% [markdown]
# ## model

# %%
X_train, y_train, df_origin = load_data(path, target)

d_train = Dataset(X_train, y_train)
if kernel_type == 'global':
    d_train.compute_rbf_kernel(gamma)
elif kernel_type == 'local':
    d_train.compute_local_rbf_kernel(gamma)
else:
    raise KeyError('kernel_type must be either "global" or "local"')
print('Done.', flush=True)

# Prototypes
if num_prototypes > 0:
    print('Computing prototypes...', end='', flush=True)
    prototype_indices = select_prototypes(d_train.K, num_prototypes)

    prototypes = d_train.X[prototype_indices]
    prototype_labels = d_train.y[prototype_indices]

    sorted_by_y_indices = prototype_labels.argsort()
    prototypes_sorted = prototypes[sorted_by_y_indices]
    prototype_labels = prototype_labels[sorted_by_y_indices]
    print('Done.', flush=True)
    print(prototype_indices.sort()[0].tolist())

    # Criticisms
    if num_criticisms > 0:
        print('Computing criticisms...', end='', flush=True)
        criticism_indices = select_criticisms(d_train.K, prototype_indices, num_criticisms, regularizer)

        criticisms = d_train.X[criticism_indices]
        criticism_labels = d_train.y[criticism_indices]

        sorted_by_y_indices = criticism_labels.argsort()
        criticisms_sorted = criticisms[sorted_by_y_indices]
        criticism_labels = criticism_labels[sorted_by_y_indices]
        print('Done.', flush=True)
        print(criticism_indices.sort()[0].tolist())
# Out:
# workclass 9
# education 16
# marital.status 7
# occupation 15
# relationship 6
# race 5
# sex 2
# native.country 42
# Done.
# Computing prototypes...Done.
# [193, 2147, 3862, 4426, 4908, 5611, 6808, 6899, 7814, 8247, 8320, 9393, 10440, 12257, 12778, 16270, 16414, 16520, 17719, 20478, 20970, 21650, 22147, 22856, 24101, 25749, 26317, 27196, 27840, 28968, 30736, 32004]
# Computing criticisms...Done.
# [2094, 6446, 8370, 10324, 15777, 23747, 24873, 26398, 26434, 27814]

# %% [markdown]
# ## prototype

# %%
df_origin.loc[prototype_indices, :]
# Out:
#        age         workclass  fnlwgt     education  education.num  \
# 12257   23           Private  173851  Some-college             10
# 30736   33  Self-emp-not-inc   99761     Bachelors             13
# 5611    30           Private   27207          11th              7
# 16270   65                 ?  105017     Bachelors             13
# 8247    46           Private   34377    Assoc-acdm             12
# 2147    38           Private  217349     Assoc-voc             11
# 6899    46         Local-gov  102076       HS-grad              9
# 32004   25           Private   74977  Some-college             10
# 22856   29      Self-emp-inc  266070     Bachelors             13
# 28968   41  Self-emp-not-inc  117012       Masters             14
# 12778   33           Private  181091     Bachelors             13
# 6808    28           Private  115971  Some-college             10
# 22147   67      Self-emp-inc  116517     Bachelors             13
# 24101   39  Self-emp-not-inc  106347  Some-college             10
# 7814    30           Private  219838          12th              8
# 25749   40  Self-emp-not-inc  129298       HS-grad              9
# 16520   36           Private  182074       HS-grad              9
# 9393    35           Private  377798     Bachelors             13
# 10440   34           Private  213722       HS-grad              9
# 21650   41           Private  152529     Bachelors             13
# 27840   24           Private  239663  Some-college             10
# 8320    24           Private  314823       HS-grad              9
# 3862    39           Private  117166          10th              6
# 17719   49           Private   54260     Bachelors             13
# 193     72  Self-emp-not-inc  285408   Prof-school             15
# 20478   34  Self-emp-not-inc   80933       HS-grad              9
# 27196   23           Private  217961       HS-grad              9
# 20970   35                 ?   98989           9th              5
# 26317   32           Private   53373  Some-college             10
# 4908    40           Private  130760     Assoc-voc             11
# 16414   29           Private   31360  Some-college             10
# 4426    60                 ?   24215          10th              6
#
#            marital.status         occupation    relationship  \
# 12257       Never-married       Craft-repair   Not-in-family
# 30736       Never-married      Other-service   Not-in-family
# 5611   Married-civ-spouse       Craft-repair         Husband
# 16270  Married-civ-spouse                  ?         Husband
# 8247   Married-civ-spouse       Craft-repair         Husband
# 2147             Divorced     Prof-specialty   Not-in-family
# 6899             Divorced       Adm-clerical       Unmarried
# 32004  Married-civ-spouse       Adm-clerical            Wife
# 22856            Divorced     Prof-specialty   Not-in-family
# 28968       Never-married    Exec-managerial   Not-in-family
# 12778  Married-civ-spouse       Adm-clerical         Husband
# 6808             Divorced       Adm-clerical       Unmarried
# 22147             Widowed      Other-service       Unmarried
# 24101            Divorced              Sales       Unmarried
# 7814             Divorced  Machine-op-inspct   Not-in-family
# 25749  Married-civ-spouse      Other-service         Husband
# 16520       Never-married       Adm-clerical  Other-relative
# 9393        Never-married     Prof-specialty   Not-in-family
# 10440       Never-married  Handlers-cleaners       Own-child
# 21650       Never-married     Prof-specialty   Not-in-family
# 27840  Married-civ-spouse       Adm-clerical         Husband
# 8320        Never-married              Sales       Own-child
# 3862   Married-civ-spouse  Machine-op-inspct         Husband
# 17719  Married-civ-spouse     Prof-specialty         Husband
# 193    Married-civ-spouse     Prof-specialty         Husband
# 20478            Divorced    Farming-fishing   Not-in-family
# 27196       Never-married       Craft-repair       Unmarried
# 20970            Divorced                  ?       Own-child
# 26317  Married-civ-spouse       Craft-repair         Husband
# 4908   Married-civ-spouse    Exec-managerial         Husband
# 16414       Never-married    Farming-fishing       Own-child
# 4426             Divorced                  ?   Not-in-family
#
#                      race     sex  capital.gain  capital.loss  hours.per.week  \
# 12257               White    Male             0             0              40
# 30736               White  Female             0             0              15
# 5611                White    Male             0             0              45
# 16270               White    Male             0             0              40
# 8247                White    Male             0             0              40
# 2147                White  Female         14344             0              40
# 6899                White  Female             0             0              25
# 32004               White  Female             0             0              40
# 22856               White  Female             0             0              80
# 28968               White  Female             0             0              55
# 12778               White    Male             0             0              60
# 6808                White  Female             0             0              40
# 22147               White  Female             0             0              35
# 24101               White    Male             0             0              47
# 7814                White    Male             0             0              40
# 25749               White    Male             0             0              45
# 16520               White    Male             0             0              40
# 9393                White    Male             0             0              50
# 10440               White    Male             0             0              40
# 21650               White    Male             0             0              40
# 27840               White    Male             0             0              15
# 8320                White    Male             0             0              40
# 3862                White    Male          2635             0              40
# 17719               White    Male             0             0              40
# 193                 White    Male             0          2246              28
# 20478               White    Male             0             0              40
# 27196               White    Male             0             0              45
# 20970  Amer-Indian-Eskimo    Male             0             0              38
# 26317               White    Male             0             0              36
# 4908                White    Male             0             0              50
# 16414               White    Male             0             0              40
# 4426   Amer-Indian-Eskimo  Female             0             0              10
#
#                    native.country  income
# 12257               United-States       0
# 30736               United-States       0
# 5611                United-States       0
# 16270               United-States       0
# 8247                United-States       1
# 2147                United-States       1
# 6899                United-States       0
# 32004               United-States       0
# 22856               United-States       0
# 28968               United-States       0
# 12778                        Iran       1
# 6808                United-States       0
# 22147               United-States       0
# 24101               United-States       0
# 7814                United-States       0
# 25749               United-States       0
# 16520               United-States       0
# 9393                United-States       1
# 10440               United-States       0
# 21650               United-States       1
# 27840               United-States       0
# 8320           Dominican-Republic       0
# 3862                United-States       0
# 17719               United-States       1
# 193                 United-States       1
# 20478               United-States       0
# 27196  Outlying-US(Guam-USVI-etc)       0
# 20970               United-States       0
# 26317               United-States       0
# 4908                United-States       1
# 16414               United-States       0
# 4426                United-States       0

# %% [markdown]
# ## criticism

# %%
df_origin.loc[criticism_indices, :]
# Out:
#        age         workclass  fnlwgt     education  education.num  \
# 10324   28           Private  259840     Bachelors             13
# 2094    46      Self-emp-inc  192779   Prof-school             15
# 8370    24           Private  184400       HS-grad              9
# 6446    29  Self-emp-not-inc   29616       HS-grad              9
# 27814   35       Federal-gov  182898       HS-grad              9
# 23747   46           Private  165953     Bachelors             13
# 26398   19  Self-emp-not-inc  137578       HS-grad              9
# 15777   23           Private  388811       HS-grad              9
# 26434   30           Private  251411  Some-college             10
# 24873   41           Private  213019     Assoc-voc             11
#
#            marital.status        occupation relationship                race  \
# 10324  Married-civ-spouse             Sales      Husband               White
# 2094   Married-civ-spouse    Prof-specialty      Husband               White
# 8370        Never-married  Transport-moving    Own-child  Asian-Pac-Islander
# 6446        Never-married   Farming-fishing    Own-child               White
# 27814  Married-civ-spouse      Adm-clerical      Husband               White
# 23747  Married-civ-spouse      Adm-clerical      Husband               White
# 26398       Never-married     Other-service    Own-child               White
# 15777       Never-married      Adm-clerical    Own-child               White
# 26434            Divorced      Adm-clerical    Unmarried               White
# 24873  Married-civ-spouse      Tech-support         Wife               White
#
#           sex  capital.gain  capital.loss  hours.per.week native.country  \
# 10324    Male             0             0              60  United-States
# 2094     Male         15024             0              60  United-States
# 8370     Male             0             0              30              ?
# 6446     Male             0             0              65  United-States
# 27814    Male             0             0              40  United-States
# 23747    Male             0             0              45  United-States
# 26398    Male             0             0              53  United-States
# 15777  Female             0             0              40  United-States
# 26434  Female             0             0              40  United-States
# 24873  Female             0             0              38  United-States
#
#        income
# 10324       1
# 2094        1
# 8370        0
# 6446        0
# 27814       0
# 23747       1
# 26398       0
# 15777       0
# 26434       0
# 24873       1

# %% [markdown]
# Reference: [MMD-critic](https://github.com/maxidl/MMD-critic)
